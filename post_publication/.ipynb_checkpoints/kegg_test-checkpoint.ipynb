# %%
# !date
import pandas as pd
import numpy as np
import sys
sys.path.append('../dev')

import utils
import enrich

pd.options.display.max_colwidth = 100
import os
# Out:
# Mon Jul 15 15:39:48 PDT 2024

# %% [markdown]
# Input: kegg orthologs
#
# Maps to: reactions
#
# enriches: reactions against pathways
#
# display_input = True -> instead of displaying the reactions found in the pathways, displays the kegg orthologs instead
#
# note: display_gene_symbol doesn't do anything for kegg. With gocams, it is the default, and sets the gene symbol to be displayed instead of uniprot IDs, which are the backend data type in reactome.

# %%
enrich.enrich_wrapper('kegg_test_ko.csv','ko',method='set',fpath = '../test_data/processed/', kegg = True, display_input = True,  enrich_against = 'pathway')
# Out:
# kegg functionality: map kegg orthologs or ECs to reactions and enrich reactions against pathways or modules. Reactions are treated as "sets." Custom addition or removal of entities not implemented yet. Weighted enrichment against pathways is slow due to large sizes; enrich_against for this is set to "module" as default. Certain non-meaningful pathways such as k01100 "Metabolic Pathways" are removed from enrichment.
# 100%|█████████████████████████████████████████████████| 48/48 [00:00<00:00, 8111.79it/s]
# Analysis run on 79 entities from 27 out of 28 input genes
#                                         title  pval (uncorrected)  \
# 0                Glycolysis / Gluconeogenesis        9.320789e-19
# 1                         Pyruvate metabolism        1.703289e-10
# 2   Chloroalkane and chloroalkene degradation        6.229512e-06
# 3                   Citrate cycle (TCA cycle)        1.264370e-05
# 4                           Carbon metabolism        1.224404e-04
# ...

# %% [markdown]
# **Weighted Enrichment**
#
# Input: kegg orthologs
#
# Maps to: reactions
#
# enriches: reactions against modules
#
#
# default: displays the reactions found in the pathways

# %%
enrich.enrich_wrapper('kegg_test_ko.csv','ko',method='ncHGT',fpath = '../test_data/processed/', kegg = True, display_input = True)
# Out:
# kegg functionality: map kegg orthologs or ECs to reactions and enrich reactions against pathways or modules. Reactions are treated as "sets." Custom addition or removal of entities not implemented yet. Weighted enrichment against pathways is slow due to large sizes; enrich_against for this is set to "module" as default. Certain non-meaningful pathways such as k01100 "Metabolic Pathways" are removed from enrichment.
# 100%|██████████████████████████████████████████████████| 26/26 [00:00<00:00, 163.11it/s]
# Analysis run on 20 entities from 27 out of 28 input genes
#                                                        title  \
# 0                 Pyruvate oxidation, pyruvate => acetyl-CoA
# 1  Glycolysis (Embden-Meyerhof pathway), glucose => pyruvate
# 2   Glycolysis, core module involving three-carbon compounds
#
#    pval (uncorrected)  # entities in list  #entities in model  \
# 0        8.290478e-12                   6                   6
# ...

# %% [markdown]
# Input: kegg orthologs
#
# Maps to: reactions
#
# enriches: reactions against modules
#
#
# default: displays the reactions found in the pathways

# %%
enrich.enrich_wrapper('kegg_test_ko.csv','ko',method='set',fpath = '../test_data/processed/', kegg = True, display_input = True)
# Out:
# kegg functionality: map kegg orthologs or ECs to reactions and enrich reactions against pathways or modules. Reactions are treated as "sets." Custom addition or removal of entities not implemented yet. Weighted enrichment against pathways is slow due to large sizes; enrich_against for this is set to "module" as default. Certain non-meaningful pathways such as k01100 "Metabolic Pathways" are removed from enrichment.
# 100%|████████████████████████████████████████████████| 26/26 [00:00<00:00, 13292.53it/s]
# Analysis run on 20 entities from 27 out of 28 input genes
#                                                        title  \
# 0                 Pyruvate oxidation, pyruvate => acetyl-CoA
# 1  Glycolysis (Embden-Meyerhof pathway), glucose => pyruvate
# 2   Glycolysis, core module involving three-carbon compounds
#
#    pval (uncorrected)  # entities in list  #entities in model  \
# 0        1.345849e-12                   6                   6
# ...

# %% [markdown]
# Input: kegg orthologs
#
# Maps to: reactions
#
# enriches: reactions against modules
#
# default: displays the reactions found in the pathways

# %%
enrich.enrich_wrapper('kegg_test_ko.csv','ko',method='set',fpath = '../test_data/processed/', kegg = True, display_input = False, enrich_against = 'pathway')
# Out:
# kegg functionality: map kegg orthologs or ECs to reactions and enrich reactions against pathways or modules. Reactions are treated as "sets." Custom addition or removal of entities not implemented yet. Weighted enrichment against pathways is slow due to large sizes; enrich_against for this is set to "module" as default. Certain non-meaningful pathways such as k01100 "Metabolic Pathways" are removed from enrichment.
# 100%|████████████████████████████████████████████████| 48/48 [00:00<00:00, 14368.16it/s]
# Analysis run on 79 entities from 27 out of 28 input genes
#                                         title  pval (uncorrected)  \
# 0                Glycolysis / Gluconeogenesis        9.320789e-19
# 1                         Pyruvate metabolism        1.703289e-10
# 2   Chloroalkane and chloroalkene degradation        6.229512e-06
# 3                   Citrate cycle (TCA cycle)        1.264370e-05
# 4                           Carbon metabolism        1.224404e-04
# ...

# %% [markdown]
# Input: EC numbers (second argument should be 'enzyme')
# Maps to: reactions
# enriches: reactions against pathways
#
# default: displays the reactions found in the pathways

# %%
 enrich.enrich_wrapper('kegg_test_ec.csv','enzyme',method='set',fpath = '../test_data/processed/', kegg = True, enrich_against = 'pathway')
# Out:
# kegg functionality: map kegg orthologs or ECs to reactions and enrich reactions against pathways or modules. Reactions are treated as "sets." Custom addition or removal of entities not implemented yet. Weighted enrichment against pathways is slow due to large sizes; enrich_against for this is set to "module" as default. Certain non-meaningful pathways such as k01100 "Metabolic Pathways" are removed from enrichment.
# 100%|█████████████████████████████████████████████████| 27/27 [00:00<00:00, 6598.28it/s]
# Analysis run on 41 entities from 13 out of 14 input genes
#                                           title  pval (uncorrected)  \
# 0                  Glycolysis / Gluconeogenesis        5.630106e-21
# 1                     Pentose phosphate pathway        7.306845e-07
# 2  Microbial metabolism in diverse environments        5.967443e-06
# 3                          Galactose metabolism        6.863091e-06
# 4                             Carbon metabolism        2.329022e-05
# ...

# %% [markdown]
# **Weighted Enrichment**
#
# EC numbers against modules

# %%
 enrich.enrich_wrapper('kegg_test_ec.csv','enzyme',method='ncHGT',fpath = '../test_data/processed/', kegg = True, enrich_against = 'module')
# Out:
# kegg functionality: map kegg orthologs or ECs to reactions and enrich reactions against pathways or modules. Reactions are treated as "sets." Custom addition or removal of entities not implemented yet. Weighted enrichment against pathways is slow due to large sizes; enrich_against for this is set to "module" as default. Certain non-meaningful pathways such as k01100 "Metabolic Pathways" are removed from enrichment.
# 100%|██████████████████████████████████████████████████| 13/13 [00:00<00:00, 273.57it/s]
#  not found in dictionary
#  not found in dictionary
# Analysis run on 15 entities from 13 out of 14 input genes
#                                                                          title  \
# 0                        Nucleotide sugar biosynthesis, glucose => UDP-glucose
# 1          Reductive pentose phosphate cycle, glyceraldehyde-3P => ribulose-5P
# 2                    Glycolysis (Embden-Meyerhof pathway), glucose => pyruvate
# ...

# %% [markdown]
# ***I need to follow up and see if the 0.00e+00 is an underflow error or something serious.***

# %% [markdown]
# Input: EC
#
# Maps to: reactions
#
# enriches: reactions against pathways
#
# display_input = True -> instead of displaying the reactions found in the pathways, displays the ECs instead

# %%
enrich.enrich_wrapper('kegg_test_ec.csv','enzyme',method='set',fpath = '../test_data/processed/', kegg = True, display_input = True, enrich_against = 'pathway')
# Out:
# kegg functionality: map kegg orthologs or ECs to reactions and enrich reactions against pathways or modules. Reactions are treated as "sets." Custom addition or removal of entities not implemented yet. Weighted enrichment against pathways is slow due to large sizes; enrich_against for this is set to "module" as default. Certain non-meaningful pathways such as k01100 "Metabolic Pathways" are removed from enrichment.
# 100%|████████████████████████████████████████████████| 27/27 [00:00<00:00, 10266.18it/s]
# Analysis run on 41 entities from 13 out of 14 input genes
#                                           title  pval (uncorrected)  \
# 0                  Glycolysis / Gluconeogenesis        5.630106e-21
# 1                     Pentose phosphate pathway        7.306845e-07
# 2  Microbial metabolism in diverse environments        5.967443e-06
# 3                          Galactose metabolism        6.863091e-06
# 4                             Carbon metabolism        2.329022e-05
# ...
