# %%
import pandas as pd
import numpy as np
import sys
sys.path.append('../dev')

import utils
import enrich_ as enrich

pd.options.display.max_colwidth = 300
pd.set_option('display.max_rows', None)

# !date
# Out:
# Tue Mar 12 17:01:45 PDT 2024

# %% [markdown]
# Below are all the enrichment results at FDR 0.1 used to produce Figures 4 and 5.

# %% [markdown]
# # p97 Inhibitors
#
# Wang et al., 2022
#
# https://www.sciencedirect.com/science/article/pii/S2451945621004827
#
# shRNA knockdown of p97 in a colon cancer cell line.

# %%
p97_step = enrich.enrich_wrapper('P97.csv','uniprot',FDR = 0.1, method='set', fpath = '../test_data/processed',table_number = 1)
p97_step
# Out:
# 100%|████████████████████████████████████████████| 480/480 [00:00<00:00, 16996.47it/s]
# Analysis run on 338 entities from 270 out of 766 input genes
# <style type="text/css">
# #T_90ed8 caption {
#   caption-side: top;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_90ed8">
#   <caption>Table SAA: P97 combined up/downregulated proteins, unweighted set method, FDR = 0.1.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90ed8_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_90ed8_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_90ed8_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_90ed8_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_90ed8_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %%
p97_standard = enrich.enrich_wrapper('P97.csv','uniprot', FDR = 0.1, method='standard', fpath = '../test_data/processed', table_number = 2)
p97_standard
# Out:
# 100%|████████████████████████████████████████████| 480/480 [00:00<00:00, 17953.95it/s]
# <style type="text/css">
# #T_00297 caption {
#   caption-side: top;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_00297">
#   <caption>Table SAB: P97 combined up/downregulated proteins, standard method, FDR = 0.1.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00297_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_00297_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_00297_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_00297_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_00297_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
#       <th id="T_00297_level0_col5" class="col_heading level0 col5" >url</th>
#     </tr>
# ...

# %%
p97_weighted = enrich.enrich_wrapper('P97.csv','uniprot', FDR = 0.1, method='ncHGT', fpath = '../test_data/processed', table_number = 3)
p97_weighted
# Out:
# 100%|███████████████████████████████████████████████| 480/480 [00:42<00:00, 11.22it/s]
# Analysis run on 338 entities from 270 out of 766 input genes
# <style type="text/css">
# #T_b223e caption {
#   caption-side: top;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_b223e">
#   <caption>Table SAC: P97 combined up/downregulated proteins, weighted set method, FDR = 0.1.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b223e_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_b223e_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_b223e_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_b223e_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_b223e_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %% [markdown]
# # Dilated and Arrhythmogenic Cardiomyopathy
#
# Reichart et al., 2022
#
# https://www.science.org/doi/10.1126/science.abo1984?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub%20%200pubmed#supplementary-materials
#
# snRNA seq on human left and right ventricles from healthy and diseased donors. 5 genotypes: LMNA, RBM20, PKP2, TTN, and PVneg (pathogenic variant negative)
#
#
# cardiomyocytes: tables S7,8 of Reichart et al
#
# fibroblasts: tables S16,17 of Reichart et al
#
# smooth muscle cells: tables S23-24 of Reichart et al

# %% [markdown]
# ## Left Ventricle Cardiomyocytes

# %% [markdown]
# ### LMNA

# %%
LMNA_set = enrich.enrich_wrapper('LMNA_CM_comb.csv','Gene Symbol',method='set',FDR = 0.1,fpath = '../test_data/processed/', table_number = 4)
LMNA_set
# Out:
# 100%|████████████████████████████████████████████| 299/299 [00:00<00:00, 16470.28it/s]
# Analysis run on 191 entities from 141 out of 689 input genes
# <style type="text/css">
# #T_52255 caption {
#   caption-side: top;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_52255">
#   <caption>Table SAD: LMNA cardiomyocytes combined up/downregulated genes, unweighted set method, FDR = 0.1.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_52255_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_52255_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_52255_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_52255_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_52255_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %%
LMNA_standard= enrich.enrich_wrapper('LMNA_CM_comb.csv','Gene Symbol',method='standard',FDR = 0.1,fpath = '../test_data/processed/', table_number = 5)
LMNA_standard
# Out:
# 100%|████████████████████████████████████████████| 299/299 [00:00<00:00, 18158.74it/s]
# <style type="text/css">
# #T_260f0 caption {
#   caption-side: top;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_260f0">
#   <caption>Table SAE: LMNA cardiomyocytes combined up/downregulated genes, standard method, FDR = 0.1.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_260f0_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_260f0_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_260f0_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_260f0_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_260f0_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
#       <th id="T_260f0_level0_col5" class="col_heading level0 col5" >url</th>
# ...

# %%
LMNA_weighted  = enrich.enrich_wrapper('LMNA_CM_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.1,fpath = '../test_data/processed/', table_number = 6)
LMNA_weighted
# Out:
#  71%|█████████████████████████████████▏             | 211/299 [01:20<00:25,  3.42it/s]

# %% [markdown]
# ### RBM20

# %%
RBM20_step = enrich.enrich_wrapper('RBM20_CM_comb.csv','Gene Symbol',method='set',FDR = 0.1,fpath = '../test_data/processed/', table_number = 7)
RBM20_step

# %%
RBM20_standard= enrich.enrich_wrapper('RBM20_CM_comb.csv','Gene Symbol',method='standard',FDR = 0.1,fpath = '../test_data/processed/',table_number = 8)
RBM20_standard

# %%
RBM20_weighted = enrich.enrich_wrapper('RBM20_CM_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.1,fpath = '../test_data/processed/',table_number = 9)
RBM20_weighted

# %% [markdown]
# ### PKP2

# %%
PKP2_step = enrich.enrich_wrapper('PKP2_CM_comb.csv','Gene Symbol',method='set',FDR = 0.1,fpath = '../test_data/processed/',table_number = 10)
PKP2_step

# %%
PKP2_standard = enrich.enrich_wrapper('PKP2_CM_comb.csv','Gene Symbol',method='standard',FDR = 0.1,fpath = '../test_data/processed/',table_number = 11)
PKP2_standard

# %%
PKP2_weighted = enrich.enrich_wrapper('PKP2_CM_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.1,fpath = '../test_data/processed/',table_number = 12)
PKP2_weighted

# %% [markdown]
# ### TTN

# %%
TTN_step = enrich.enrich_wrapper('TTN_CM_comb.csv','Gene Symbol',method='set',FDR = 0.1,fpath = '../test_data/processed/',table_number = 13)
TTN_step

# %%
TTN_standard = enrich.enrich_wrapper('TTN_CM_comb.csv','Gene Symbol',method='standard',FDR = 0.1,fpath = '../test_data/processed/',table_number = 14)
TTN_standard

# %%
TTN_weighted = enrich.enrich_wrapper('TTN_CM_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.1,fpath = '../test_data/processed/',table_number = 15)
TTN_weighted

# %% [markdown]
# ### PVneg

# %%
PVneg_step = enrich.enrich_wrapper('PVneg_CM_comb.csv','Gene Symbol',method='set',FDR = 0.1,fpath = '../test_data/processed/',table_number = 16)
PVneg_step

# %%
PVneg_standard = enrich.enrich_wrapper('PVneg_CM_comb.csv','Gene Symbol',method='standard',FDR = 0.1,fpath = '../test_data/processed/',table_number = 17)
PVneg_standard

# %%
PVneg_weighted = enrich.enrich_wrapper('PVneg_CM_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.1,fpath = '../test_data/processed/',table_number = 18)
PVneg_weighted

# %% [markdown]
# ## Left Ventricle Fibroblasts

# %% [markdown]
# ### LMNA

# %%
LMNA_step = enrich.enrich_wrapper('LMNA_FB_comb.csv','Gene Symbol',method='set',FDR = 0.1,fpath = '../test_data/processed/',table_number = 19)
LMNA_step

# %%
LMNA_standard = enrich.enrich_wrapper('LMNA_FB_comb.csv','Gene Symbol',method='standard',FDR = 0.1,fpath = '../test_data/processed/',table_number = 20)
LMNA_standard

# %%
LMNA_weighted = enrich.enrich_wrapper('LMNA_FB_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.1,fpath = '../test_data/processed/',table_number = 21)
LMNA_weighted

# %% [markdown]
# ### RBM20

# %%
RBM20_set = enrich.enrich_wrapper('RBM20_FB_comb.csv','Gene Symbol',method='set',FDR = 0.1,fpath = '../test_data/processed/',table_number = 22)
RBM20_set

# %%
RBM20_standard = enrich.enrich_wrapper('RBM20_FB_comb.csv','Gene Symbol',method='standard',FDR = 0.1,fpath = '../test_data/processed/',table_number = 23)
RBM20_standard

# %%
RBM20_weighted = enrich.enrich_wrapper('RBM20_FB_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.1,fpath = '../test_data/processed/',table_number = 24)
RBM20_weighted

# %% [markdown]
# ### PKP2

# %%
PKP2_set = enrich.enrich_wrapper('PKP2_FB_comb.csv','Gene Symbol',method='set',FDR = 0.1,fpath = '../test_data/processed/',table_number = 25)
PKP2_set

# %%
PKP2_standard = enrich.enrich_wrapper('PKP2_FB_comb.csv','Gene Symbol',method='standard',FDR = 0.1,fpath = '../test_data/processed/',table_number = 26)
PKP2_standard

# %%
PKP2_weighted = enrich.enrich_wrapper('PKP2_FB_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.1,fpath = '../test_data/processed/',table_number = 27)
PKP2_weighted

# %% [markdown]
# ### TTN

# %%
TTN_set = enrich.enrich_wrapper('TTN_FB_comb.csv','Gene Symbol',method='set',FDR = 0.1,fpath = '../test_data/processed/',table_number = 28)
TTN_set

# %%
TTN_standard = enrich.enrich_wrapper('TTN_FB_comb.csv','Gene Symbol',method='standard',FDR = 0.1,fpath = '../test_data/processed/',table_number = 29)
TTN_standard

# %%
TTN_weighted = enrich.enrich_wrapper('TTN_FB_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.1,fpath = '../test_data/processed/',table_number = 30)
TTN_weighted

# %% [markdown]
# ### PVneg

# %%
PVneg_set = enrich.enrich_wrapper('PVneg_FB_comb.csv','Gene Symbol',method='set',FDR = 0.1 ,fpath = '../test_data/processed/',table_number = 31)
PVneg_set

# %%
PVneg_standard = enrich.enrich_wrapper('PVneg_FB_comb.csv','Gene Symbol',method='standard',FDR = 0.1 ,fpath = '../test_data/processed/',table_number = 32)
PVneg_standard

# %%
PVneg_weighted = enrich.enrich_wrapper('PVneg_FB_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.1 ,fpath = '../test_data/processed/',table_number = 33)
PVneg_weighted

# %% [markdown]
# ## Left Ventricle Mural Smooth Muscle Cells

# %% [markdown]
# ### LMNA

# %%
LMNA_set = enrich.enrich_wrapper('LMNA_SMC_comb.csv','Gene Symbol',method='set',FDR = 0.1,fpath = '../test_data/processed/',table_number = 34)
LMNA_set

# %%
LMNA_standard = enrich.enrich_wrapper('LMNA_SMC_comb.csv','Gene Symbol',method='standard',FDR = 0.1 ,fpath = '../test_data/processed/',table_number = 35)
LMNA_standard

# %%
LMNA_weighted = enrich.enrich_wrapper('LMNA_SMC_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.1,fpath = '../test_data/processed/',table_number = 36)
LMNA_weighted

# %% [markdown]
# ### RBM20

# %%
RBM20_set = enrich.enrich_wrapper('RBM20_SMC_comb.csv','Gene Symbol',method='set',FDR = 0.1,fpath = '../test_data/processed/',table_number = 37)
RBM20_set

# %%
RBM20_standard = enrich.enrich_wrapper('RBM20_SMC_comb.csv','Gene Symbol',method='standard',FDR = 0.1,fpath = '../test_data/processed/',table_number = 38)
RBM20_standard

# %%
RBM20_weighted = enrich.enrich_wrapper('RBM20_SMC_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.1,fpath = '../test_data/processed/',table_number = 39)
RBM20_weighted

# %% [markdown]
# ### PKP2

# %%
PKP2_set = enrich.enrich_wrapper('PKP2_SMC_comb.csv','Gene Symbol',method='set',FDR = 0.1,fpath = '../test_data/processed/',table_number = 40)
PKP2_set

# %%
PKP2_standard = enrich.enrich_wrapper('PKP2_SMC_comb.csv','Gene Symbol',method='standard',FDR = 0.1,fpath = '../test_data/processed/',table_number = 41)
PKP2_standard

# %%
PKP2_weighted = enrich.enrich_wrapper('PKP2_SMC_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.1,fpath = '../test_data/processed/',table_number = 42)
PKP2_weighted

# %% [markdown]
# ### TTN

# %%
TTN_set = enrich.enrich_wrapper('TTN_SMC_comb.csv','Gene Symbol',method='set',FDR = 0.1,fpath = '../test_data/processed/',table_number = 43)
TTN_set

# %%
TTN_standard = enrich.enrich_wrapper('TTN_SMC_comb.csv','Gene Symbol',method='standard',FDR = 0.1,fpath = '../test_data/processed/',table_number = 44)
TTN_standard

# %%
TTN_weighted = enrich.enrich_wrapper('TTN_SMC_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.1,fpath = '../test_data/processed/',table_number = 45)
TTN_weighted

# %% [markdown]
# ### PVneg

# %%
PVneg_set = enrich.enrich_wrapper('PVneg_SMC_comb.csv','Gene Symbol',method='set',FDR = 0.1,fpath = '../test_data/processed/',table_number = 46)
PVneg_set

# %%
PVneg_standard = enrich.enrich_wrapper('PVneg_SMC_comb.csv','Gene Symbol',method='standard',FDR = 0.1,fpath = '../test_data/processed/',table_number = 47)
PVneg_standard

# %%
PVneg_weighted = enrich.enrich_wrapper('PVneg_SMC_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.1,fpath = '../test_data/processed/',table_number = 48)
PVneg_weighted

# %% [markdown]
# # Platelets in SARS-CoV-2
#
# Kanth manne et al., 2020
#
# https://ashpublications.org/blood/article/136/11/1317/461106/Platelet-gene-expression-and-function-in-patients
#
# RNAseq in platelets from patients with covid-19 vs healthy donors. There were 6 ICU and 4 nonICU patients.

# %%
platelets_up_set = enrich.enrich_wrapper('platelets_up.csv','Gene Symbol',method='set',FDR = 0.1,fpath = '../test_data/processed/',table_number = 49)
platelets_up_set

# %%
platelets_up_standard = enrich.enrich_wrapper('platelets_up.csv','Gene Symbol',method='standard',FDR = 0.1,fpath = '../test_data/processed/',table_number = 50)
platelets_up_standard

# %%
platelets_up_weighted = enrich.enrich_wrapper('platelets_up.csv','Gene Symbol',method='ncHGT',FDR = 0.1,fpath = '../test_data/processed/',table_number = 51)
platelets_up_weighted

# %%
platelets_down_set = enrich.enrich_wrapper('platelets_down.csv','Gene Symbol',method='set',FDR = 0.1,fpath = '../test_data/processed/',table_number = 52)
platelets_down_set

# %%
platelets_down_standard = enrich.enrich_wrapper('platelets_down.csv','Gene Symbol',method='standard',FDR = 0.1,fpath = '../test_data/processed/',table_number = 53)
platelets_down_standard

# %%
platelets_down_weighted = enrich.enrich_wrapper('platelets_down.csv','Gene Symbol',method='ncHGT',FDR = 0.1,fpath = '../test_data/processed/',table_number = 54)
platelets_down_weighted

# %% [markdown]
# # Non Alcoholic Fatty Liver Disease
#
# Govaere et al., 2023
#
# https://www.nature.com/articles/s42255-023-00775-1
#
# NAFLD. Paired transcriptomics and proteomics in 306 patients to find signatures of active steatohepatitis and severe fibrosis.

# %%
GS2_step= enrich.enrich_wrapper('Goavere_S2.csv','Gene Symbol',method='set',FDR = 0.1,fpath = '../test_data/processed/', table_number = 55)
GS2_step

# %%
GS2_standard = enrich.enrich_wrapper('Goavere_S2.csv','Gene Symbol',method='standard',FDR = 0.1,fpath = '../test_data/processed/', table_number = 56)
GS2_standard

# %%
GS2_weighted = enrich.enrich_wrapper('Goavere_S2.csv','Gene Symbol',method='ncHGT',FDR = 0.1,fpath = '../test_data/processed/', table_number = 57)
GS2_weighted

# %% [markdown]
# # Astrocytes in Aging Mouse Brains across 4 brain regions
#
# Boisvert et al., 2018
#
# https://www.sciencedirect.com/science/article/pii/S221112471731848X?via%3Dihub#app3
#
# RNA seq on astrocytes isolated from different brain regions in 4 month and 2 year old mice. Most brain regions had ~200 up and ~200 downregulated genes, but most of those were also differentially expressed between brain regions.
#
# In fig 2B, it appears that cerebellum and hypothalamus are the best candidates, as the 3 biological replicates (3 mice) cluster together by region and age. The hypothalamus looks a little cleaner than cerebellum.

# %% [markdown]
# The paper says they filtered based on "FPKM > 1, Adj P value < 0.05, and pulldown/input > 0.75"

# %% [markdown]
# ## Hypothalamus

# %%
astro_HTH_set = enrich.enrich_wrapper('astro_HTH_comb.csv','Gene Symbol',method='set',FDR = 0.1,fpath = '../test_data/processed/',table_number = 58)
astro_HTH_set

# %%
astro_HTH_standard = enrich.enrich_wrapper('astro_HTH_comb.csv','Gene Symbol',method='standard',FDR = 0.1,fpath = '../test_data/processed/',table_number = 59)
astro_HTH_standard

# %% [markdown]
# **Note on C4B:**
#
# C4B is listed twice, but that is due to  P0C0L4 and P0C0L5 both being officially listed as uniprot accession IDs for C4B, which affected our results when we used SimpleMine.
#
# P0C0L4 seems to actually correspond to C4A (C4A and C4B are paralogs). However, C4b can be derived from either the C4A gene product or the C4B gene product, and so both genes are listed as members of a set, and both are annotated to the pathway. GO-CAMs use uniprot accession IDs, so P0C0L4 and P0C0L5 are listed in the model for enrichment. When the input list of genes was mapped from gene symbols to uniprot accession IDs, both P0C0L4 and P0C0L5 were hits for the GOCAM.
#
# Why both accession IDs are officially associated with C4B is unclear, since they correspond to C4A and C4B on UniProt's website. We believe the issue is that the genes are cross listed as aliases for one another, which led to both uniprot accession ID's being associated with C4B.

# %%
astro_HTH_weighted = enrich.enrich_wrapper('astro_HTH_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.1,fpath = '../test_data/processed/',table_number = 60)
astro_HTH_weighted

# %% [markdown]
# ## Cerebellum

# %%
astro_CB_set = enrich.enrich_wrapper('astro_CB_comb.csv','Gene Symbol',method='set',FDR = 0.1,fpath = '../test_data/processed/',table_number = 61)
astro_CB_set

# %%
astro_CB_standard = enrich.enrich_wrapper('astro_CB_comb.csv','Gene Symbol',method='standard',FDR = 0.1,fpath = '../test_data/processed/',table_number = 62)
astro_CB_standard

# %%
astro_CB_weighted = enrich.enrich_wrapper('astro_CB_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.1,fpath = '../test_data/processed/',table_number = 63)
astro_CB_weighted

# %% [markdown]
# # Macrophage activation
#
# Orrechioni et al., 2019
#
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6543837/pdf/fimmu-10-01084.pdf
#
# In vitro classically activated vs alternatively activated macrophpages

# %%
mac_set = enrich.enrich_wrapper('mac_comb.csv','Gene Symbol',method='set',FDR = 0.1,fpath = '../test_data/processed/',table_number = 64)
mac_set

# %%
mac_standard = enrich.enrich_wrapper('mac_comb.csv','Gene Symbol',method='standard',FDR = 0.1,fpath = '../test_data/processed/',table_number = 65)
mac_standard

# %%
mac_weighted = enrich.enrich_wrapper('mac_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.1,fpath = '../test_data/processed/',table_number = 66)
mac_weighted
