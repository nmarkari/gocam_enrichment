# %%
import pandas as pd
import numpy as np
import sys
sys.path.append('../dev')

import utils
import enrich_ as enrich

pd.options.display.max_colwidth = 300
pd.set_option('display.max_rows', None)

# !date
# Out:
# Mon Feb 19 12:09:49 PST 2024

# %% [markdown]
# # p97 Inhibitors
#
# Wang et al., 2022
#
# https://www.sciencedirect.com/science/article/pii/S2451945621004827
#
# shRNA knockdown of p97 in a colon cancer cell line.

# %%
p97_step = enrich.enrich_wrapper('P97.csv','uniprot',FDR = 0.05, method='set', fpath = '../test_data/processed',table_number = 1)
p97_step
# Out:
# 100%|██████████████████████████████████████| 480/480 [00:00<00:00, 15036.27it/s]
# Analysis run on 338 entities from 270 out of 766 input genes
# <style type="text/css">
# #T_f39dd caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_f39dd">
#   <caption>Table S1: P97 combined up/downregulated proteins, unweighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f39dd_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_f39dd_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_f39dd_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_f39dd_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_f39dd_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %%
p97_standard = enrich.enrich_wrapper('P97.csv','uniprot', FDR = 0.05, method='standard', fpath = '../test_data/processed', table_number = 2)
p97_standard
# Out:
# 100%|██████████████████████████████████████| 480/480 [00:00<00:00, 16725.78it/s]
# <style type="text/css">
# #T_0a6c1 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_0a6c1">
#   <caption>Table S2: P97 combined up/downregulated proteins, standard method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a6c1_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_0a6c1_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_0a6c1_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_0a6c1_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_0a6c1_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
#       <th id="T_0a6c1_level0_col5" class="col_heading level0 col5" >url</th>
#     </tr>
#   </thead>
# ...

# %%
p97_weighted = enrich.enrich_wrapper('P97.csv','uniprot', FDR = 0.05, method='ncHGT', fpath = '../test_data/processed', table_number = 3)
p97_weighted
# Out:
# 100%|█████████████████████████████████████████| 480/480 [00:45<00:00, 10.48it/s]
# Analysis run on 338 entities from 270 out of 766 input genes
# <style type="text/css">
# #T_26fa1 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_26fa1">
#   <caption>Table S3: P97 combined up/downregulated proteins, weighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26fa1_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_26fa1_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_26fa1_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_26fa1_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_26fa1_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %% [markdown]
# # Dilated and Arrhythmogenic Cardiomyopathy
#
# Reichart et al., 2022
#
# https://www.science.org/doi/10.1126/science.abo1984?url_ver=Z39.88-2003&rfr_id=ori:rid:crossref.org&rfr_dat=cr_pub%20%200pubmed#supplementary-materials
#
# snRNA seq on human left and right ventricles from healthy and diseased donors. 5 genotypes: LMNA, RBM20, PKP2, TTN, and PVneg (pathogenic variant negative)
#
#
# cardiomyocytes: tables S7,8 of Reichart et al
#
# fibroblasts: tables S16,17 of Reichart et al
#
# smooth muscle cells: tables S23-24 of Reichart et al

# %% [markdown]
# ## Left Ventricle Cardiomyocytes

# %% [markdown]
# ### LMNA

# %%
LMNA_set = enrich.enrich_wrapper('LMNA_CM_comb.csv','Gene Symbol',method='set',FDR = 0.05,fpath = '../test_data/processed/', table_number = 4)
LMNA_set
# Out:
# 100%|██████████████████████████████████████| 299/299 [00:00<00:00, 15944.07it/s]
# Analysis run on 191 entities from 141 out of 689 input genes
# <style type="text/css">
# #T_410c1 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_410c1">
#   <caption>Table S4: LMNA cardiomyocytes combined up/downregulated genes, unweighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_410c1_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_410c1_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_410c1_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_410c1_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_410c1_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %%
LMNA_standard= enrich.enrich_wrapper('LMNA_CM_comb.csv','Gene Symbol',method='standard',FDR = 0.05,fpath = '../test_data/processed/', table_number = 5)
LMNA_standard
# Out:
# 100%|██████████████████████████████████████| 299/299 [00:00<00:00, 15988.38it/s]
# <style type="text/css">
# #T_a9088 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_a9088">
#   <caption>Table S5: LMNA cardiomyocytes combined up/downregulated genes, standard method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9088_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_a9088_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_a9088_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_a9088_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_a9088_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
#       <th id="T_a9088_level0_col5" class="col_heading level0 col5" >url</th>
#     </tr>
# ...

# %%
LMNA_weighted  = enrich.enrich_wrapper('LMNA_CM_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.05,fpath = '../test_data/processed/', table_number = 6)
LMNA_weighted
# Out:
# 100%|█████████████████████████████████████████| 299/299 [02:01<00:00,  2.46it/s]
# Analysis run on 191 entities from 141 out of 689 input genes
# <style type="text/css">
# #T_1b959 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_1b959">
#   <caption>Table S6: LMNA cardiomyocytes combined up/downregulated genes, weighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b959_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_1b959_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_1b959_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_1b959_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_1b959_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %% [markdown]
# ### RBM20

# %%
RBM20_step = enrich.enrich_wrapper('RBM20_CM_comb.csv','Gene Symbol',method='set',FDR = 0.05,fpath = '../test_data/processed/', table_number = 7)
RBM20_step
# Out:
# 100%|██████████████████████████████████████| 207/207 [00:00<00:00, 17563.23it/s]
# Analysis run on 156 entities from 115 out of 533 input genes
# <style type="text/css">
# #T_a9081 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_a9081">
#   <caption>Table S7: RBM20 cardiomyocytes combined up/downregulated genes, unweighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9081_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_a9081_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_a9081_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_a9081_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_a9081_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %%
RBM20_standard= enrich.enrich_wrapper('RBM20_CM_comb.csv','Gene Symbol',method='standard',FDR = 0.05,fpath = '../test_data/processed/',table_number = 8)
RBM20_standard
# Out:
# 100%|██████████████████████████████████████| 207/207 [00:00<00:00, 17383.19it/s]
# <style type="text/css">
# #T_9f901 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_9f901">
#   <caption>Table S8: RBM20 cardiomyocytes combined up/downregulated genes, standard method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9f901_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_9f901_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_9f901_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_9f901_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_9f901_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
#       <th id="T_9f901_level0_col5" class="col_heading level0 col5" >url</th>
# ...

# %%
RBM20_weighted = enrich.enrich_wrapper('RBM20_CM_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.05,fpath = '../test_data/processed/',table_number = 9)
RBM20_weighted
# Out:
# 100%|█████████████████████████████████████████| 207/207 [00:47<00:00,  4.40it/s]
# Analysis run on 156 entities from 115 out of 533 input genes
# <style type="text/css">
# #T_58232 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_58232">
#   <caption>Table S9: RBM20 cardiomyocytes combined up/downregulated genes, weighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_58232_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_58232_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_58232_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_58232_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_58232_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %% [markdown]
# ### PKP2

# %%
PKP2_step = enrich.enrich_wrapper('PKP2_CM_comb.csv','Gene Symbol',method='set',FDR = 0.05,fpath = '../test_data/processed/',table_number = 10)
PKP2_step
# Out:
# 100%|██████████████████████████████████████| 302/302 [00:00<00:00, 17554.98it/s]
# Analysis run on 151 entities from 94 out of 403 input genes
# <style type="text/css">
# #T_0624b caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_0624b">
#   <caption>Table S10: PKP2 cardiomyocytes combined up/downregulated genes, unweighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0624b_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_0624b_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_0624b_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_0624b_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_0624b_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %%
PKP2_standard = enrich.enrich_wrapper('PKP2_CM_comb.csv','Gene Symbol',method='standard',FDR = 0.05,fpath = '../test_data/processed/',table_number = 11)
PKP2_standard
# Out:
# 100%|██████████████████████████████████████| 302/302 [00:00<00:00, 17210.09it/s]
# <style type="text/css">
# #T_cb3fd caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_cb3fd">
#   <caption>Table S11: PKP2 cardiomyocytes combined up/downregulated genes, standard method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb3fd_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_cb3fd_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_cb3fd_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_cb3fd_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_cb3fd_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
#       <th id="T_cb3fd_level0_col5" class="col_heading level0 col5" >url</th>
# ...

# %%
PKP2_weighted = enrich.enrich_wrapper('PKP2_CM_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.05,fpath = '../test_data/processed/',table_number = 12)
PKP2_weighted
# Out:
# 100%|█████████████████████████████████████████| 302/302 [01:35<00:00,  3.15it/s]
# Analysis run on 151 entities from 94 out of 403 input genes
# <style type="text/css">
# #T_918a2 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_918a2">
#   <caption>Table S12: PKP2 cardiomyocytes combined up/downregulated genes, weighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_918a2_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_918a2_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_918a2_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_918a2_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_918a2_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %% [markdown]
# ### TTN

# %%
TTN_step = enrich.enrich_wrapper('TTN_CM_comb.csv','Gene Symbol',method='set',FDR = 0.05,fpath = '../test_data/processed/',table_number = 13)
TTN_step
# Out:
# 100%|██████████████████████████████████████| 362/362 [00:00<00:00, 17538.65it/s]
# Analysis run on 193 entities from 133 out of 602 input genes
# <style type="text/css">
# #T_371f2 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_371f2">
#   <caption>Table S13: TTN cardiomyocytes combined up/downregulated genes, unweighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_371f2_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_371f2_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_371f2_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_371f2_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_371f2_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %%
TTN_standard = enrich.enrich_wrapper('TTN_CM_comb.csv','Gene Symbol',method='standard',FDR = 0.05,fpath = '../test_data/processed/',table_number = 14)
TTN_standard
# Out:
# 100%|██████████████████████████████████████| 362/362 [00:00<00:00, 16767.95it/s]
# <style type="text/css">
# #T_e7f92 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_e7f92">
#   <caption>Table S14: TTN cardiomyocytes combined up/downregulated genes, standard method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7f92_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_e7f92_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_e7f92_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_e7f92_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_e7f92_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
#       <th id="T_e7f92_level0_col5" class="col_heading level0 col5" >url</th>
#     </tr>
# ...

# %%
TTN_weighted = enrich.enrich_wrapper('TTN_CM_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.05,fpath = '../test_data/processed/',table_number = 15)
TTN_weighted
# Out:
# 100%|█████████████████████████████████████████| 362/362 [01:58<00:00,  3.05it/s]
# Analysis run on 193 entities from 133 out of 602 input genes
# <style type="text/css">
# #T_75106 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_75106">
#   <caption>Table S15: TTN cardiomyocytes combined up/downregulated genes, weighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75106_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_75106_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_75106_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_75106_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_75106_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %% [markdown]
# ### PVneg

# %%
PVneg_step = enrich.enrich_wrapper('PVneg_CM_comb.csv','Gene Symbol',method='set',FDR = 0.05,fpath = '../test_data/processed/',table_number = 16)
PVneg_step
# Out:
# 100%|████████████████████████████████████████| 93/93 [00:00<00:00, 16786.60it/s]
# Analysis run on 59 entities from 42 out of 178 input genes
# <style type="text/css">
# #T_47840 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_47840">
#   <caption>Table S16: PVneg cardiomyocytes combined up/downregulated genes, unweighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_47840_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_47840_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_47840_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_47840_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_47840_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %%
PVneg_standard = enrich.enrich_wrapper('PVneg_CM_comb.csv','Gene Symbol',method='standard',FDR = 0.05,fpath = '../test_data/processed/',table_number = 17)
PVneg_standard
# Out:
# 100%|████████████████████████████████████████| 93/93 [00:00<00:00, 16594.50it/s]
# <style type="text/css">
# #T_7501a caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_7501a">
#   <caption>Table S17: PVneg cardiomyocytes combined up/downregulated genes, standard method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7501a_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_7501a_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_7501a_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_7501a_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_7501a_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
#       <th id="T_7501a_level0_col5" class="col_heading level0 col5" >url</th>
# ...

# %%
PVneg_weighted = enrich.enrich_wrapper('PVneg_CM_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.05,fpath = '../test_data/processed/',table_number = 18)
PVneg_weighted
# Out:
# 100%|███████████████████████████████████████████| 93/93 [00:46<00:00,  2.00it/s]
# Analysis run on 59 entities from 42 out of 178 input genes
# <style type="text/css">
# #T_dbcb4 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_dbcb4">
#   <caption>Table S18: PVneg cardiomyocytes combined up/downregulated genes, weighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dbcb4_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_dbcb4_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_dbcb4_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_dbcb4_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_dbcb4_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %% [markdown]
# ## Left Ventricle Fibroblasts

# %% [markdown]
# ### LMNA

# %%
LMNA_step = enrich.enrich_wrapper('LMNA_FB_comb.csv','Gene Symbol',method='set',FDR = 0.05,fpath = '../test_data/processed/',table_number = 19)
LMNA_step
# Out:
# 100%|██████████████████████████████████████| 401/401 [00:00<00:00, 17013.28it/s]
# Analysis run on 284 entities from 234 out of 872 input genes
# <style type="text/css">
# #T_279d1 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_279d1">
#   <caption>Table S19: LMNA fibroblasts combined up/downregulated genes, unweighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_279d1_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_279d1_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_279d1_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_279d1_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_279d1_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %%
LMNA_standard = enrich.enrich_wrapper('LMNA_FB_comb.csv','Gene Symbol',method='standard',FDR = 0.05,fpath = '../test_data/processed/',table_number = 20)
LMNA_standard
# Out:
# 100%|██████████████████████████████████████| 401/401 [00:00<00:00, 16269.10it/s]
# <style type="text/css">
# #T_322df caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_322df">
#   <caption>Table S20: LMNA fibroblasts combined up/downregulated genes, standard method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_322df_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_322df_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_322df_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_322df_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_322df_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
#       <th id="T_322df_level0_col5" class="col_heading level0 col5" >url</th>
#     </tr>
# ...

# %%
LMNA_weighted = enrich.enrich_wrapper('LMNA_FB_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.05,fpath = '../test_data/processed/',table_number = 21)
LMNA_weighted
# Out:
# 100%|█████████████████████████████████████████| 401/401 [02:38<00:00,  2.52it/s]
# Analysis run on 284 entities from 234 out of 872 input genes
# <style type="text/css">
# #T_96105 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_96105">
#   <caption>Table S21: LMNA fibroblasts combined up/downregulated genes, weighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96105_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_96105_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_96105_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_96105_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_96105_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %% [markdown]
# ### RBM20

# %%
RBM20_set = enrich.enrich_wrapper('RBM20_FB_comb.csv','Gene Symbol',method='set',FDR = 0.05,fpath = '../test_data/processed/',table_number = 22)
RBM20_set
# Out:
# 100%|██████████████████████████████████████| 283/283 [00:00<00:00, 17465.72it/s]
# Analysis run on 193 entities from 163 out of 625 input genes
# <style type="text/css">
# #T_fa884 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_fa884">
#   <caption>Table S22: RBM20 fibroblasts combined up/downregulated genes, unweighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa884_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_fa884_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_fa884_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_fa884_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_fa884_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %%
RBM20_standard = enrich.enrich_wrapper('RBM20_FB_comb.csv','Gene Symbol',method='standard',FDR = 0.05,fpath = '../test_data/processed/',table_number = 23)
RBM20_standard
# Out:
# 100%|██████████████████████████████████████| 283/283 [00:00<00:00, 15974.32it/s]
# <style type="text/css">
# #T_36cb2 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_36cb2">
#   <caption>Table S23: RBM20 fibroblasts combined up/downregulated genes, standard method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_36cb2_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_36cb2_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_36cb2_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_36cb2_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_36cb2_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
#       <th id="T_36cb2_level0_col5" class="col_heading level0 col5" >url</th>
#     </tr>
# ...

# %%
RBM20_weighted = enrich.enrich_wrapper('RBM20_FB_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.05,fpath = '../test_data/processed/',table_number = 24)
RBM20_weighted
# Out:
# 100%|█████████████████████████████████████████| 283/283 [02:12<00:00,  2.14it/s]
# Analysis run on 193 entities from 163 out of 625 input genes
# <style type="text/css">
# #T_f5f15 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_f5f15">
#   <caption>Table S24: RBM20 fibroblasts combined up/downregulated genes, weighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f5f15_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_f5f15_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_f5f15_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_f5f15_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_f5f15_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %% [markdown]
# ### PKP2

# %%
PKP2_set = enrich.enrich_wrapper('PKP2_FB_comb.csv','Gene Symbol',method='set',FDR = 0.05,fpath = '../test_data/processed/',table_number = 25)
PKP2_set
# Out:
# 100%|██████████████████████████████████████| 358/358 [00:00<00:00, 17384.61it/s]
# Analysis run on 239 entities from 191 out of 725 input genes
# <style type="text/css">
# #T_65721 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_65721">
#   <caption>Table S25: PKP2 fibroblasts combined up/downregulated genes, unweighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_65721_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_65721_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_65721_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_65721_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_65721_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %%
PKP2_standard = enrich.enrich_wrapper('PKP2_FB_comb.csv','Gene Symbol',method='standard',FDR = 0.05,fpath = '../test_data/processed/',table_number = 26)
PKP2_standard
# Out:
# 100%|██████████████████████████████████████| 358/358 [00:00<00:00, 16778.15it/s]
# <style type="text/css">
# #T_06e00 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_06e00">
#   <caption>Table S26: PKP2 fibroblasts combined up/downregulated genes, standard method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_06e00_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_06e00_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_06e00_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_06e00_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_06e00_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
#       <th id="T_06e00_level0_col5" class="col_heading level0 col5" >url</th>
#     </tr>
# ...

# %%
PKP2_weighted = enrich.enrich_wrapper('PKP2_FB_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.05,fpath = '../test_data/processed/',table_number = 27)
PKP2_weighted
# Out:
# 100%|█████████████████████████████████████████| 358/358 [02:09<00:00,  2.76it/s]
# Analysis run on 239 entities from 191 out of 725 input genes
# <style type="text/css">
# #T_5eeec caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_5eeec">
#   <caption>Table S27: PKP2 fibroblasts combined up/downregulated genes, weighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5eeec_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_5eeec_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_5eeec_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_5eeec_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_5eeec_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %% [markdown]
# ### TTN

# %%
TTN_set = enrich.enrich_wrapper('TTN_FB_comb.csv','Gene Symbol',method='set',FDR = 0.05,fpath = '../test_data/processed/',table_number = 28)
TTN_set
# Out:
# 100%|██████████████████████████████████████| 461/461 [00:00<00:00, 17204.15it/s]
# Analysis run on 359 entities from 311 out of 1092 input genes
# <style type="text/css">
# #T_c69bf caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_c69bf">
#   <caption>Table S28: TTN fibroblasts combined up/downregulated genes, unweighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c69bf_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_c69bf_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_c69bf_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_c69bf_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_c69bf_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %%
TTN_standard = enrich.enrich_wrapper('TTN_FB_comb.csv','Gene Symbol',method='standard',FDR = 0.05,fpath = '../test_data/processed/',table_number = 29)
TTN_standard
# Out:
# 100%|██████████████████████████████████████| 461/461 [00:00<00:00, 16936.07it/s]
# <style type="text/css">
# #T_dd2f7 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_dd2f7">
#   <caption>Table S29: TTN fibroblasts combined up/downregulated genes, standard method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dd2f7_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_dd2f7_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_dd2f7_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_dd2f7_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_dd2f7_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
#       <th id="T_dd2f7_level0_col5" class="col_heading level0 col5" >url</th>
#     </tr>
# ...

# %%
TTN_weighted = enrich.enrich_wrapper('TTN_FB_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.05,fpath = '../test_data/processed/',table_number = 30)
TTN_weighted
# Out:
# 100%|█████████████████████████████████████████| 461/461 [05:03<00:00,  1.52it/s]
# Analysis run on 359 entities from 311 out of 1092 input genes
# <style type="text/css">
# #T_6b193 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_6b193">
#   <caption>Table S30: TTN fibroblasts combined up/downregulated genes, weighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6b193_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_6b193_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_6b193_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_6b193_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_6b193_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %% [markdown]
# ### PVneg

# %%
PVneg_set = enrich.enrich_wrapper('PVneg_FB_comb.csv','Gene Symbol',method='set',FDR = 0.1 ,fpath = '../test_data/processed/',table_number = 31)
PVneg_set
# Out:
# 100%|██████████████████████████████████████| 452/452 [00:00<00:00, 16281.29it/s]
# Analysis run on 396 entities from 338 out of 1135 input genes
# <style type="text/css">
# #T_ae3e6 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_ae3e6">
#   <caption>Table S31: PVneg fibroblasts combined up/downregulated genes, unweighted set method, FDR = 0.1.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ae3e6_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_ae3e6_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_ae3e6_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_ae3e6_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_ae3e6_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %%
PVneg_standard = enrich.enrich_wrapper('PVneg_FB_comb.csv','Gene Symbol',method='standard',FDR = 0.1 ,fpath = '../test_data/processed/',table_number = 32)
PVneg_standard
# Out:
# 100%|██████████████████████████████████████| 452/452 [00:00<00:00, 15846.88it/s]
# <style type="text/css">
# #T_0c12c caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_0c12c">
#   <caption>Table S32: PVneg fibroblasts combined up/downregulated genes, standard method, FDR = 0.1.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c12c_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_0c12c_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_0c12c_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_0c12c_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_0c12c_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
#       <th id="T_0c12c_level0_col5" class="col_heading level0 col5" >url</th>
#     </tr>
# ...

# %%
PVneg_weighted = enrich.enrich_wrapper('PVneg_FB_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.1 ,fpath = '../test_data/processed/',table_number = 33)
PVneg_weighted
# Out:
# 100%|█████████████████████████████████████████| 452/452 [03:01<00:00,  2.49it/s]
# Analysis run on 396 entities from 338 out of 1135 input genes
# <style type="text/css">
# #T_d9cec caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_d9cec">
#   <caption>Table S33: PVneg fibroblasts combined up/downregulated genes, weighted set method, FDR = 0.1.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9cec_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_d9cec_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_d9cec_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_d9cec_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_d9cec_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %% [markdown]
# ## Left Ventricle Mural Smooth Muscle Cells

# %% [markdown]
# ### LMNA

# %%
LMNA_set = enrich.enrich_wrapper('LMNA_SMC_comb.csv','Gene Symbol',method='set',FDR = 0.05,fpath = '../test_data/processed/',table_number = 34)
LMNA_set
# Out:
# 100%|██████████████████████████████████████| 326/326 [00:00<00:00, 16314.02it/s]
# Analysis run on 210 entities from 161 out of 633 input genes
# <style type="text/css">
# #T_88f77 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_88f77">
#   <caption>Table S34: LMNA smooth muscle cells combined up/downregulated genes, unweighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88f77_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_88f77_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_88f77_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_88f77_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_88f77_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %%
LMNA_standard = enrich.enrich_wrapper('LMNA_SMC_comb.csv','Gene Symbol',method='standard',FDR = 0.1 ,fpath = '../test_data/processed/',table_number = 35)
LMNA_standard
# Out:
# 100%|██████████████████████████████████████| 326/326 [00:00<00:00, 15945.32it/s]
# <style type="text/css">
# #T_a9b09 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_a9b09">
#   <caption>Table S35: LMNA smooth muscle cells combined up/downregulated genes, standard method, FDR = 0.1.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9b09_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_a9b09_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_a9b09_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_a9b09_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_a9b09_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
#       <th id="T_a9b09_level0_col5" class="col_heading level0 col5" >url</th>
# ...

# %%
LMNA_weighted = enrich.enrich_wrapper('LMNA_SMC_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.05,fpath = '../test_data/processed/',table_number = 36)
LMNA_weighted
# Out:
# 100%|█████████████████████████████████████████| 326/326 [02:09<00:00,  2.52it/s]
# Analysis run on 210 entities from 161 out of 633 input genes
# <style type="text/css">
# #T_de975 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_de975">
#   <caption>Table S36: LMNA smooth muscle cells combined up/downregulated genes, weighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_de975_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_de975_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_de975_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_de975_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_de975_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %% [markdown]
# ### RBM20

# %%
RBM20_set = enrich.enrich_wrapper('RBM20_SMC_comb.csv','Gene Symbol',method='set',FDR = 0.05,fpath = '../test_data/processed/',table_number = 37)
RBM20_set
# Out:
# 100%|██████████████████████████████████████| 195/195 [00:00<00:00, 16203.85it/s]
# Analysis run on 135 entities from 103 out of 435 input genes
# <style type="text/css">
# #T_d8089 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_d8089">
#   <caption>Table S37: RBM20 smooth muscle cells combined up/downregulated genes, unweighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8089_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_d8089_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_d8089_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_d8089_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_d8089_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %%
RBM20_standard = enrich.enrich_wrapper('RBM20_SMC_comb.csv','Gene Symbol',method='standard',FDR = 0.05,fpath = '../test_data/processed/',table_number = 38)
RBM20_standard
# Out:
# 100%|██████████████████████████████████████| 195/195 [00:00<00:00, 17262.70it/s]
# <style type="text/css">
# #T_109a9 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_109a9">
#   <caption>Table S38: RBM20 smooth muscle cells combined up/downregulated genes, standard method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_109a9_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_109a9_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_109a9_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_109a9_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_109a9_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
#       <th id="T_109a9_level0_col5" class="col_heading level0 col5" >url</th>
# ...

# %%
RBM20_weighted = enrich.enrich_wrapper('RBM20_SMC_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.05,fpath = '../test_data/processed/',table_number = 39)
RBM20_weighted
# Out:
# 100%|█████████████████████████████████████████| 195/195 [01:15<00:00,  2.58it/s]
# Analysis run on 135 entities from 103 out of 435 input genes
# <style type="text/css">
# #T_2e4f8 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_2e4f8">
#   <caption>Table S39: RBM20 smooth muscle cells combined up/downregulated genes, weighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e4f8_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_2e4f8_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_2e4f8_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_2e4f8_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_2e4f8_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %% [markdown]
# ### PKP2

# %%
PKP2_set = enrich.enrich_wrapper('PKP2_SMC_comb.csv','Gene Symbol',method='set',FDR = 0.05,fpath = '../test_data/processed/',table_number = 40)
PKP2_set
# Out:
# 100%|██████████████████████████████████████| 185/185 [00:00<00:00, 16042.22it/s]
# Analysis run on 92 entities from 65 out of 309 input genes
# <style type="text/css">
# #T_354a6 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_354a6">
#   <caption>Table S40: PKP2 smooth muscle cells combined up/downregulated genes, unweighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_354a6_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_354a6_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_354a6_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_354a6_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_354a6_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %%
PKP2_standard = enrich.enrich_wrapper('PKP2_SMC_comb.csv','Gene Symbol',method='standard',FDR = 0.05,fpath = '../test_data/processed/',table_number = 41)
PKP2_standard
# Out:
# 100%|██████████████████████████████████████| 185/185 [00:00<00:00, 15716.64it/s]
# <style type="text/css">
# #T_5449a caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_5449a">
#   <caption>Table S41: PKP2 smooth muscle cells combined up/downregulated genes, standard method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5449a_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_5449a_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_5449a_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_5449a_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_5449a_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
#       <th id="T_5449a_level0_col5" class="col_heading level0 col5" >url</th>
# ...

# %%
PKP2_weighted = enrich.enrich_wrapper('PKP2_SMC_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.05,fpath = '../test_data/processed/',table_number = 42)
PKP2_weighted
# Out:
# 100%|█████████████████████████████████████████| 185/185 [01:21<00:00,  2.27it/s]
# Analysis run on 92 entities from 65 out of 309 input genes
# <style type="text/css">
# #T_49489 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_49489">
#   <caption>Table S42: PKP2 smooth muscle cells combined up/downregulated genes, weighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49489_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_49489_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_49489_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_49489_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_49489_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %% [markdown]
# ### TTN

# %%
TTN_set = enrich.enrich_wrapper('TTN_SMC_comb.csv','Gene Symbol',method='set',FDR = 0.05,fpath = '../test_data/processed/',table_number = 43)
TTN_set
# Out:
# 100%|██████████████████████████████████████| 268/268 [00:00<00:00, 16117.37it/s]
# Analysis run on 139 entities from 103 out of 396 input genes
# <style type="text/css">
# #T_1f09d caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_1f09d">
#   <caption>Table S43: TTN smooth muscle cells combined up/downregulated genes, unweighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f09d_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_1f09d_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_1f09d_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_1f09d_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_1f09d_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %%
TTN_standard = enrich.enrich_wrapper('TTN_SMC_comb.csv','Gene Symbol',method='standard',FDR = 0.05,fpath = '../test_data/processed/',table_number = 44)
TTN_standard
# Out:
# 100%|██████████████████████████████████████| 268/268 [00:00<00:00, 15864.64it/s]
# <style type="text/css">
# #T_3a5df caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_3a5df">
#   <caption>Table S44: TTN smooth muscle cells combined up/downregulated genes, standard method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a5df_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_3a5df_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_3a5df_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_3a5df_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_3a5df_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
#       <th id="T_3a5df_level0_col5" class="col_heading level0 col5" >url</th>
# ...

# %%
TTN_weighted = enrich.enrich_wrapper('TTN_SMC_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.05,fpath = '../test_data/processed/',table_number = 45)
TTN_weighted
# Out:
# 100%|█████████████████████████████████████████| 268/268 [01:43<00:00,  2.59it/s]
# Analysis run on 139 entities from 103 out of 396 input genes
# <style type="text/css">
# #T_0779d caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_0779d">
#   <caption>Table S45: TTN smooth muscle cells combined up/downregulated genes, weighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0779d_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_0779d_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_0779d_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_0779d_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_0779d_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %% [markdown]
# ### PVneg

# %%
PVneg_set = enrich.enrich_wrapper('PVneg_SMC_comb.csv','Gene Symbol',method='set',FDR = 0.05,fpath = '../test_data/processed/',table_number = 46)
PVneg_set
# Out:
# 100%|██████████████████████████████████████| 324/324 [00:00<00:00, 16269.25it/s]
# Analysis run on 256 entities from 221 out of 686 input genes
# <style type="text/css">
# #T_4dc5f caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_4dc5f">
#   <caption>Table S46: PVneg smooth muscle cells combined up/downregulated genes, unweighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4dc5f_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_4dc5f_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_4dc5f_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_4dc5f_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_4dc5f_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %%
PVneg_standard = enrich.enrich_wrapper('PVneg_SMC_comb.csv','Gene Symbol',method='standard',FDR = 0.05,fpath = '../test_data/processed/',table_number = 47)
PVneg_standard
# Out:
# 100%|██████████████████████████████████████| 324/324 [00:00<00:00, 15890.12it/s]
# <style type="text/css">
# #T_74bd9 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_74bd9">
#   <caption>Table S47: PVneg smooth muscle cells combined up/downregulated genes, standard method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74bd9_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_74bd9_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_74bd9_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_74bd9_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_74bd9_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
#       <th id="T_74bd9_level0_col5" class="col_heading level0 col5" >url</th>
# ...

# %%
PVneg_weighted = enrich.enrich_wrapper('PVneg_SMC_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.05,fpath = '../test_data/processed/',table_number = 48)
PVneg_weighted
# Out:
# 100%|█████████████████████████████████████████| 324/324 [00:39<00:00,  8.12it/s]
# Analysis run on 256 entities from 221 out of 686 input genes
# <style type="text/css">
# #T_875e1 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_875e1">
#   <caption>Table S48: PVneg smooth muscle cells combined up/downregulated genes, weighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_875e1_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_875e1_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_875e1_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_875e1_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_875e1_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %% [markdown]
# # Platelets in SARS-CoV-2
#
# Kanth manne et al., 2020
#
# https://ashpublications.org/blood/article/136/11/1317/461106/Platelet-gene-expression-and-function-in-patients
#
# RNAseq in platelets from patients with covid-19 vs healthy donors. There were 6 ICU and 4 nonICU patients.

# %%
platelets_up_set = enrich.enrich_wrapper('platelets_up.csv','Gene Symbol',method='set',FDR = 0.05,fpath = '../test_data/processed/',table_number = 49)
platelets_up_set
# Out:
# 100%|██████████████████████████████████████| 482/482 [00:00<00:00, 16302.48it/s]
# Analysis run on 423 entities from 365 out of 1172 input genes
# <style type="text/css">
# #T_2c84f caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_2c84f">
#   <caption>Table S49: platelets up, unweighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c84f_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_2c84f_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_2c84f_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_2c84f_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_2c84f_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %%
platelets_up_standard = enrich.enrich_wrapper('platelets_up.csv','Gene Symbol',method='standard',FDR = 0.05,fpath = '../test_data/processed/',table_number = 50)
platelets_up_standard
# Out:
# 100%|██████████████████████████████████████| 482/482 [00:00<00:00, 15927.57it/s]
# <style type="text/css">
# #T_cc9fd caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_cc9fd">
#   <caption>Table S50: platelets up, standard method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cc9fd_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_cc9fd_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_cc9fd_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_cc9fd_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_cc9fd_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
#       <th id="T_cc9fd_level0_col5" class="col_heading level0 col5" >url</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
platelets_up_weighted = enrich.enrich_wrapper('platelets_up.csv','Gene Symbol',method='ncHGT',FDR = 0.05,fpath = '../test_data/processed/',table_number = 51)
platelets_up_weighted
# Out:
# 100%|█████████████████████████████████████████| 482/482 [01:23<00:00,  5.75it/s]
# Analysis run on 423 entities from 365 out of 1172 input genes
# <style type="text/css">
# #T_a56fb caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_a56fb">
#   <caption>Table S51: platelets up, weighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a56fb_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_a56fb_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_a56fb_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_a56fb_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_a56fb_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %%
platelets_down_set = enrich.enrich_wrapper('platelets_down.csv','Gene Symbol',method='set',FDR = 0.05,fpath = '../test_data/processed/',table_number = 52)
platelets_down_set
# Out:
# 100%|██████████████████████████████████████| 436/436 [00:00<00:00, 16523.30it/s]
# Analysis run on 309 entities from 267 out of 1088 input genes
# <style type="text/css">
# #T_0dfe4 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_0dfe4">
#   <caption>Table S52: platelets down, unweighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0dfe4_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_0dfe4_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_0dfe4_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_0dfe4_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_0dfe4_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %%
platelets_down_standard = enrich.enrich_wrapper('platelets_down.csv','Gene Symbol',method='standard',FDR = 0.05,fpath = '../test_data/processed/',table_number = 53)
platelets_down_standard
# Out:
# 100%|██████████████████████████████████████| 436/436 [00:00<00:00, 16395.90it/s]
# <style type="text/css">
# #T_95f2d caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_95f2d">
#   <caption>Table S53: platelets down, standard method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95f2d_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_95f2d_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_95f2d_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_95f2d_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_95f2d_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
#       <th id="T_95f2d_level0_col5" class="col_heading level0 col5" >url</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
platelets_down_weighted = enrich.enrich_wrapper('platelets_down.csv','Gene Symbol',method='ncHGT',FDR = 0.05,fpath = '../test_data/processed/',table_number = 54)
platelets_down_weighted
# Out:
# 100%|█████████████████████████████████████████| 436/436 [02:21<00:00,  3.08it/s]
# Analysis run on 309 entities from 267 out of 1088 input genes
# <style type="text/css">
# #T_8a8ad caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_8a8ad">
#   <caption>Table S54: platelets down, weighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a8ad_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_8a8ad_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_8a8ad_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_8a8ad_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_8a8ad_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %% [markdown]
# # Non Alcoholic Fatty Liver Disease
#
# Govaere et al., 2023
#
# https://www.nature.com/articles/s42255-023-00775-1
#
# NAFLD. Paired transcriptomics and proteomics in 306 patients to find signatures of active steatohepatitis and severe fibrosis.

# %%
GS2_step= enrich.enrich_wrapper('Goavere_S2.csv','Gene Symbol',method='set',FDR = 0.05,fpath = '../test_data/processed/', table_number = 55)
GS2_step
# Out:
# 100%|████████████████████████████████████████| 98/98 [00:00<00:00, 15363.18it/s]
# Analysis run on 68 entities from 48 out of 118 input genes
# <style type="text/css">
# #T_7fc0f caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_7fc0f">
#   <caption>Table S55: NAFLD combined up/downregulated genes, unweighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7fc0f_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_7fc0f_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_7fc0f_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_7fc0f_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_7fc0f_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %%
GS2_standard = enrich.enrich_wrapper('Goavere_S2.csv','Gene Symbol',method='standard',FDR = 0.05,fpath = '../test_data/processed/', table_number = 56)
GS2_standard
# Out:
# 100%|████████████████████████████████████████| 98/98 [00:00<00:00, 16556.91it/s]
# <style type="text/css">
# #T_6281d caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_6281d">
#   <caption>Table S56: NAFLD combined up/downregulated genes, standard method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6281d_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_6281d_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_6281d_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_6281d_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_6281d_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
#       <th id="T_6281d_level0_col5" class="col_heading level0 col5" >url</th>
#     </tr>
#   </thead>
# ...

# %%
GS2_weighted = enrich.enrich_wrapper('Goavere_S2.csv','Gene Symbol',method='ncHGT',FDR = 0.05,fpath = '../test_data/processed/', table_number = 57)
GS2_weighted
# Out:
# 100%|███████████████████████████████████████████| 98/98 [00:01<00:00, 77.22it/s]
# Analysis run on 68 entities from 48 out of 118 input genes
# <style type="text/css">
# #T_3c3fa caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_3c3fa">
#   <caption>Table S57: NAFLD combined up/downregulated genes, weighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c3fa_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_3c3fa_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_3c3fa_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_3c3fa_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_3c3fa_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %% [markdown]
# # Astrocytes in Aging Mouse Brains across 4 brain regions
#
# Boisvert et al., 2018
#
# https://www.sciencedirect.com/science/article/pii/S221112471731848X?via%3Dihub#app3
#
# RNA seq on astrocytes isolated from different brain regions in 4 month and 2 year old mice. Most brain regions had ~200 up and ~200 downregulated genes, but most of those were also differentially expressed between brain regions.
#
# In fig 2B, it appears that cerebellum and hypothalamus are the best candidates, as the 3 biological replicates (3 mice) cluster together by region and age. The hypothalamus looks a little cleaner than cerebellum.

# %% [markdown]
# The paper says they filtered based on "FPKM > 1, Adj P value < 0.05, and pulldown/input > 0.75"

# %% [markdown]
# ## Hypothalamus

# %%
astro_HTH_set = enrich.enrich_wrapper('astro_HTH_comb.csv','Gene Symbol',method='set',FDR = 0.05,fpath = '../test_data/processed/',table_number = 58)
astro_HTH_set
# Out:
# 100%|██████████████████████████████████████| 246/246 [00:00<00:00, 16416.32it/s]
# Analysis run on 139 entities from 115 out of 416 input genes
# <style type="text/css">
# #T_52c2b caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_52c2b">
#   <caption>Table S58: astroctyes hypothalamus combined up/downregulated genes, unweighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_52c2b_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_52c2b_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_52c2b_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_52c2b_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_52c2b_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %%
astro_HTH_standard = enrich.enrich_wrapper('astro_HTH_comb.csv','Gene Symbol',method='standard',FDR = 0.05,fpath = '../test_data/processed/',table_number = 59)
astro_HTH_standard
# Out:
# 100%|██████████████████████████████████████| 246/246 [00:00<00:00, 16873.52it/s]
# <style type="text/css">
# #T_a32f6 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_a32f6">
#   <caption>Table S59: astroctyes hypothalamus combined up/downregulated genes, standard method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a32f6_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_a32f6_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_a32f6_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_a32f6_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_a32f6_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
#       <th id="T_a32f6_level0_col5" class="col_heading level0 col5" >url</th>
# ...

# %% [markdown]
# **Note on C4B:**
#
# C4B is listed twice, but that is due to  P0C0L4 and P0C0L5 both being officially listed as uniprot accession IDs for C4B, which affected our results when we used SimpleMine.
#
# P0C0L4 seems to actually correspond to C4A (C4A and C4B are paralogs). However, C4b can be derived from either the C4A gene product or the C4B gene product, and so both genes are listed as members of a set, and both are annotated to the pathway. GO-CAMs use uniprot accession IDs, so P0C0L4 and P0C0L5 are listed in the model for enrichment. When the input list of genes was mapped from gene symbols to uniprot accession IDs, both P0C0L4 and P0C0L5 were hits for the GOCAM.
#
# Why both accession IDs are officially associated with C4B is unclear, since they correspond to C4A and C4B on UniProt's website. We believe the issue is that the genes are cross listed as aliases for one another, which led to both uniprot accession ID's being associated with C4B.

# %%
astro_HTH_weighted = enrich.enrich_wrapper('astro_HTH_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.05,fpath = '../test_data/processed/',table_number = 60)
astro_HTH_weighted
# Out:
# 100%|█████████████████████████████████████████| 246/246 [00:32<00:00,  7.55it/s]
# Analysis run on 139 entities from 115 out of 416 input genes
# <style type="text/css">
# #T_85f53 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_85f53">
#   <caption>Table S60: astroctyes hypothalamus combined up/downregulated genes, weighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85f53_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_85f53_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_85f53_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_85f53_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_85f53_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %% [markdown]
# ## Cerebellum

# %%
astro_CB_set = enrich.enrich_wrapper('astro_CB_comb.csv','Gene Symbol',method='set',FDR = 0.05,fpath = '../test_data/processed/',table_number = 61)
astro_CB_set
# Out:
# 100%|██████████████████████████████████████| 310/310 [00:00<00:00, 17650.88it/s]
# Analysis run on 200 entities from 172 out of 605 input genes
# <style type="text/css">
# #T_0461c caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_0461c">
#   <caption>Table S61: astroctyes cerebellum combined up/downregulated genes, unweighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0461c_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_0461c_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_0461c_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_0461c_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_0461c_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %%
astro_CB_standard = enrich.enrich_wrapper('astro_CB_comb.csv','Gene Symbol',method='standard',FDR = 0.05,fpath = '../test_data/processed/',table_number = 62)
astro_CB_standard
# Out:
# 100%|██████████████████████████████████████| 310/310 [00:00<00:00, 16538.63it/s]
# <style type="text/css">
# #T_e34d7 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_e34d7">
#   <caption>Table S62: astroctyes cerebellum combined up/downregulated genes, standard method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e34d7_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_e34d7_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_e34d7_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_e34d7_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_e34d7_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
#       <th id="T_e34d7_level0_col5" class="col_heading level0 col5" >url</th>
# ...

# %%
astro_CB_weighted = enrich.enrich_wrapper('astro_CB_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.05,fpath = '../test_data/processed/',table_number = 63)
astro_CB_weighted
# Out:
# 100%|█████████████████████████████████████████| 310/310 [00:30<00:00, 10.19it/s]
# Analysis run on 200 entities from 172 out of 605 input genes
# <style type="text/css">
# #T_2b1dc caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_2b1dc">
#   <caption>Table S63: astroctyes cerebellum combined up/downregulated genes, weighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b1dc_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_2b1dc_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_2b1dc_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_2b1dc_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_2b1dc_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %% [markdown]
# # Macrophage activation
#
# Orrechioni et al., 2019
#
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6543837/pdf/fimmu-10-01084.pdf
#
# In vitro classically activated vs alternatively activated macrophpages

# %%
mac_set = enrich.enrich_wrapper('mac_comb.csv','Gene Symbol',method='set',FDR = 0.05,fpath = '../test_data/processed/',table_number = 64)
mac_set
# Out:
# 100%|██████████████████████████████████████| 667/667 [00:00<00:00, 16768.07it/s]
# Analysis run on 619 entities from 511 out of 1519 input genes
# <style type="text/css">
# #T_39934 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_39934">
#   <caption>Table S64: macrophages combined up/downregulated genes, unweighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_39934_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_39934_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_39934_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_39934_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_39934_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...

# %%
mac_standard = enrich.enrich_wrapper('mac_comb.csv','Gene Symbol',method='standard',FDR = 0.05,fpath = '../test_data/processed/',table_number = 65)
mac_standard
# Out:
# 100%|██████████████████████████████████████| 667/667 [00:00<00:00, 16580.14it/s]
# <style type="text/css">
# #T_b8191 caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_b8191">
#   <caption>Table S65: macrophages combined up/downregulated genes, standard method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8191_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_b8191_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_b8191_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_b8191_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_b8191_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
#       <th id="T_b8191_level0_col5" class="col_heading level0 col5" >url</th>
#     </tr>
# ...

# %%
mac_weighted = enrich.enrich_wrapper('mac_comb.csv','Gene Symbol',method='ncHGT',FDR = 0.05,fpath = '../test_data/processed/',table_number = 66)
mac_weighted
# Out:
# 100%|█████████████████████████████████████████| 667/667 [03:22<00:00,  3.30it/s]
# Analysis run on 619 entities from 511 out of 1519 input genes
# <style type="text/css">
# #T_d1bef caption {
#   caption-side: bottom;
#   font-size: 1.25em;
#   text-align: left;
#   font-weight: bold;
# }
# </style>
# <table id="T_d1bef">
#   <caption>Table S66: macrophages combined up/downregulated genes, weighted set method, FDR = 0.05.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1bef_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_d1bef_level0_col1" class="col_heading level0 col1" >pval (uncorrected)</th>
#       <th id="T_d1bef_level0_col2" class="col_heading level0 col2" ># entities in list</th>
#       <th id="T_d1bef_level0_col3" class="col_heading level0 col3" >#entities in model</th>
#       <th id="T_d1bef_level0_col4" class="col_heading level0 col4" >shared entities in gocam</th>
# ...
