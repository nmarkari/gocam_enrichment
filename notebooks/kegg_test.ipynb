# %%
# !date
import pandas as pd
import numpy as np
import sys
sys.path.append('../dev')

import utils
import enrich

pd.options.display.max_colwidth = 100
import os
# Out:
# Mon Jul  8 09:54:21 HST 2024

# %% [markdown]
# Input: kegg orthologs
# Maps to: reactions
# enriches: reactions against pathways
#
# display_input = True -> instead of displaying the reactions found in the pathways, displays the kegg orthologs instead
# note: display_gene_symbol doesn't do anything for kegg. With gocams, it is the default, and sets the gene symbol to be displayed instead of uniprot IDs, which are the backend data type in reactome.

# %%
kegg = enrich.enrich_wrapper('kegg_test_ko.csv','ko',method='set',fpath = '../test_data/processed/', kegg = True, display_input = True,return_all = True)
# Out:
# kegg functionality: map kegg orthologs or ECs to reactions and enrich reactions against pathways. Other mappings/enrichments and custom addition or removal of entities not implemented yet
# 100%|████████████████████████████████████████| 48/48 [00:00<00:00, 11753.55it/s]
# Analysis run on 79 entities from 27 out of 28 input genes

# %%
kegg[5]
# Out:
#                                         title  pval (uncorrected)  \
# 0                Glycolysis / Gluconeogenesis        9.320789e-19
# 1                         Pyruvate metabolism        1.703289e-10
# 2   Chloroalkane and chloroalkene degradation        6.229512e-06
# 3                   Citrate cycle (TCA cycle)        1.264370e-05
# 4                           Carbon metabolism        1.224404e-04
# 5           Drug metabolism - cytochrome P450        3.802876e-04
# 6  Valine, leucine and isoleucine degradation        1.533085e-03
# 7                        Galactose metabolism        2.273745e-03
#
#    # entities in list  #entities in model  \
# 0                  18                  53
# 1                  13                  65
# 2                   6                  25
# 3                   6                  28
# 4                  13                 202
# 5                   3                   8
# 6                   5                  44
# ...

# %% [markdown]
# Input: kegg orthologs
# Maps to: reactions
# enriches: reactions against pathways
#
# default: displays the reactions found in the pathways

# %%
kegg = enrich.enrich_wrapper('kegg_test_ko.csv','ko',method='set',fpath = '../test_data/processed/', kegg = True, display_input = False,return_all = True)
# Out:
# kegg functionality: map kegg orthologs or ECs to reactions and enrich reactions against pathways. Other mappings/enrichments and custom addition or removal of entities not implemented yet
# 100%|████████████████████████████████████████| 48/48 [00:00<00:00, 14623.85it/s]
# Analysis run on 79 entities from 27 out of 28 input genes

# %%
kegg[5]
# Out:
#                                         title  pval (uncorrected)  \
# 0                Glycolysis / Gluconeogenesis        9.320789e-19
# 1                         Pyruvate metabolism        1.703289e-10
# 2   Chloroalkane and chloroalkene degradation        6.229512e-06
# 3                   Citrate cycle (TCA cycle)        1.264370e-05
# 4                           Carbon metabolism        1.224404e-04
# 5           Drug metabolism - cytochrome P450        3.802876e-04
# 6  Valine, leucine and isoleucine degradation        1.533085e-03
# 7                        Galactose metabolism        2.273745e-03
#
#    # entities in list  #entities in model  \
# 0                  18                  53
# 1                  13                  65
# 2                   6                  25
# 3                   6                  28
# 4                  13                 202
# 5                   3                   8
# 6                   5                  44
# ...

# %% [markdown]
# Input: EC numbers (second argument should be 'enzyme')
# Maps to: reactions
# enriches: reactions against pathways
#
# default: displays the reactions found in the pathways

# %%
kegg = enrich.enrich_wrapper('kegg_test_ec.csv','enzyme',method='set',fpath = '../test_data/processed/', kegg = True, return_all = True)
# Out:
# kegg functionality: map kegg orthologs or ECs to reactions and enrich reactions against pathways. Other mappings/enrichments and custom addition or removal of entities not implemented yet
# 100%|████████████████████████████████████████| 27/27 [00:00<00:00, 16072.41it/s]
# Analysis run on 41 entities from 13 out of 14 input genes

# %%
kegg[5]
# Out:
#                                           title  pval (uncorrected)  \
# 0                  Glycolysis / Gluconeogenesis        5.630106e-21
# 1                     Pentose phosphate pathway        7.306845e-07
# 2  Microbial metabolism in diverse environments        5.967443e-06
# 3                          Galactose metabolism        6.863091e-06
# 4                             Carbon metabolism        2.329022e-05
# 5   Amino sugar and nucleotide sugar metabolism        2.802148e-05
# 6               Fructose and mannose metabolism        4.841043e-04
# 7             Biosynthesis of nucleotide sugars        1.675469e-03
#
#    # entities in list  #entities in model  \
# 0                  16                  53
# 1                   7                  53
# 2                  23                 942
# 3                   6                  48
# 4                  10                 202
# 5                   8                 125
# 6                   5                  66
# ...

# %% [markdown]
# Input: EC
# Maps to: reactions
# enriches: reactions against pathways
#
# display_input = True -> instead of displaying the reactions found in the pathways, displays the ECs instead

# %%
kegg = enrich.enrich_wrapper('kegg_test_ec.csv','enzyme',method='set',fpath = '../test_data/processed/', kegg = True, display_input = True, return_all = True)
# Out:
# kegg functionality: map kegg orthologs or ECs to reactions and enrich reactions against pathways. Other mappings/enrichments and custom addition or removal of entities not implemented yet
# 100%|████████████████████████████████████████| 27/27 [00:00<00:00, 14885.15it/s]
# Analysis run on 41 entities from 13 out of 14 input genes

# %%
kegg[5]
# Out:
#                                           title  pval (uncorrected)  \
# 0                  Glycolysis / Gluconeogenesis        5.630106e-21
# 1                     Pentose phosphate pathway        7.306845e-07
# 2  Microbial metabolism in diverse environments        5.967443e-06
# 3                          Galactose metabolism        6.863091e-06
# 4                             Carbon metabolism        2.329022e-05
# 5   Amino sugar and nucleotide sugar metabolism        2.802148e-05
# 6               Fructose and mannose metabolism        4.841043e-04
# 7             Biosynthesis of nucleotide sugars        1.675469e-03
#
#    # entities in list  #entities in model  \
# 0                  16                  53
# 1                   7                  53
# 2                  23                 942
# 3                   6                  48
# 4                  10                 202
# 5                   8                 125
# 6                   5                  66
# ...
