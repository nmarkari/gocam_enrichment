# %%
# !date
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats
from scipy.stats import hypergeom
from re import search
import csv

import sys
sys.path.append('../GOCAM_Project/dev')
import utils
# Out:
# Thu Dec  1 09:30:38 PST 2022

# %%
#import the reactome data
data_reactome = pd.read_csv("~/Downloads/metabolic_gocams2genes_20220728.tsv", header=0, names=["gocam", "title", "identifier","taxon","taxon_labels","modelstate"], sep="\t")
data_reactome['identifier'] = data_reactome['identifier'].apply(lambda x: x.split(','))
data_reactome['taxon_labels'] = data_reactome['taxon_labels'].apply(lambda x: x.split(','))
data_reactome['title']=data_reactome['title'].apply(lambda x: x.split('^')[0])
data_reactome['modelstate']=data_reactome['modelstate'].apply(lambda x: x.split('^')[0])
data_reactome['gocam']=data_reactome['gocam'].apply(lambda x: x[1:len(x)-1])
data_reactome = data_reactome[data_reactome['taxon_labels'].apply(lambda x: 'Homo sapiens' in x)]
data_reactome = data_reactome[['gocam','title','identifier']]
data_reactome
# Out:
#                                                gocam  \
# 0         http://model.geneontology.org/R-HSA-997272
# 1        http://model.geneontology.org/R-HSA-1296041
# 2        http://model.geneontology.org/R-HSA-5218921
# 3        http://model.geneontology.org/R-HSA-2871809
# 4        http://model.geneontology.org/R-HSA-2029485
# ...                                              ...
# 1082      http://model.geneontology.org/R-HSA-110312
# 1090  http://model.geneontology.org/596a6e0600000152
# 1092  http://model.geneontology.org/613aae0000000061
# 1095  http://model.geneontology.org/5a5fc23a00000008
# 1097  http://model.geneontology.org/5970219a00000013
#
#                                                   title  \
# 0     Inhibition of voltage gated Ca2+ channels via ...
# 1     Activation of G protein gated Potassium channe...
# 2     VEGFR2 mediated cell proliferation - imported ...
# 3     FCERI mediated Ca+2 mobilization - imported fr...
# 4     Role of phospholipids in phagocytosis - import...
# ...                                                 ...
# 1082  Translesion synthesis by REV1 - imported from:...
# 1090                                      GPI1_human_PD
# 1092                                 cGAS-STING (Human)
# 1095                    adenylate cyclase test 20180123
# 1097                                      GPI2_human_PD
#
#                                              identifier
# 0     [http://purl.obolibrary.org/obo/go/extensions/...
# 1     [http://purl.obolibrary.org/obo/go/extensions/...
# 2     [http://purl.obolibrary.org/obo/go/extensions/...
# 3     [http://purl.obolibrary.org/obo/go/extensions/...
# 4     [http://purl.obolibrary.org/obo/go/extensions/...
# ...                                                 ...
# 1082  [http://purl.obolibrary.org/obo/go/extensions/...
# 1090  [http://identifiers.org/uniprot/Q9Y2B2, http:/...
# 1092  [http://identifiers.org/uniprot/Q8N884, http:/...
# 1095  [http://identifiers.org/uniprot/Q08828, http:/...
# 1097  [http://identifiers.org/uniprot/Q9H3S5, http:/...
#
# [1087 rows x 3 columns]

# %%
data_reactome[data_reactome.title.apply(lambda x: 'Long' in x)]
# Out:
#                                            gocam  \
# 51   http://model.geneontology.org/R-HSA-9620244
# 681  http://model.geneontology.org/R-HSA-5651801
# 682   http://model.geneontology.org/R-HSA-110362
#
#                                                  title  \
# 51    Long-term potentiation - imported from: Reactome
# 681  PCNA-Dependent Long Patch Base Excision Repair...
# 682  POLB-Dependent Long Patch Base Excision Repair...
#
#                                             identifier
# 51   [http://purl.obolibrary.org/obo/go/extensions/...
# 681  [http://purl.obolibrary.org/obo/go/extensions/...
# 682  [http://purl.obolibrary.org/obo/go/extensions/...

# %%
#import the production data
data = pd.read_csv("~/Downloads/gocams2genes_20220728.txt", header=0, names=["gocam", "title", "gp_labels","identifier","taxon","taxon_label","modelstate"], sep="\t")
data['gp_labels'] = data['gp_labels'].apply(lambda x: x.split(','))
data['identifier'] = data['identifier'].apply(lambda x: x.split(','))
data['title']=data['title'].apply(lambda x: x.split('^')[0])
data['modelstate']=data['modelstate'].apply(lambda x: x.split('^')[0])
data['gocam']=data['gocam'].apply(lambda x: x[1:len(x)-1])
data_human = data[data['taxon_label'].apply(lambda x: ('Mus musculus' not in x) and ('Homo sapiens' in x))]
mouse = data[data.taxon_label.apply(lambda x: ('Mus musculus' in x) and ('Homo sapiens' not in x))]
data_human = data_human[['gocam','title','identifier']]
data_both = data[data.taxon_label.apply(lambda x: ('Mus musculus' in x)and ('Homo sapiens' in x))]
len(data_both.identifier.values[0])
# Out:
# 37

# %%
mouse = mouse.explode('identifier')
mouse.identifier.apply(lambda x: x.split('/')[-2]).value_counts()
# Out:
# mgi    482
# obo      1
# Name: identifier, dtype: int64

# %%
mouse_mgi = mouse[mouse.identifier.apply(lambda x: 'MGI:' in x)]
mouse_non_mgi = mouse[mouse.identifier.apply(lambda x: 'MGI:' not in x)]
mouse_mgi.identifier = mouse_mgi.identifier.apply(lambda x: x.split('/')[-1])

table = pd.read_csv('../data/simplemine_results.txt',sep='\t', header=3)
table['Mouse Ortholog'] = table['Mouse Ortholog'].apply(lambda x: x.split(' | '))
table = table.explode('Mouse Ortholog')
d= pd.Series(table['UniProtKB ID'].values,index=table['Mouse Ortholog'].apply(lambda x: x[:x.rfind(":")])).to_dict()
mouse_mgi['h_uniprot'] = mouse_mgi.identifier.apply(lambda x: d.get(x,'NO ORTHOLOG FOUND'))
mouse_mgi = mouse_mgi[mouse_mgi["h_uniprot"] != 'N.A.']
#just picking the first uniprot entry, because the canonical one isn't indicated in the simplemine results
mouse_mgi['identifier']=mouse_mgi['h_uniprot'].apply(lambda x: 'http://identifiers.org/uniprot/'+x.split(' | ')[0])
mouse_mgi = mouse_mgi[['gocam','title','identifier']]
# Out:
# /Users/nicholasmarkarian/opt/miniconda3/envs/gocam/lib/python3.7/site-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# /Users/nicholasmarkarian/opt/miniconda3/envs/gocam/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == "__main__":

# %%
mouse_mgi.query('gocam== "http://model.geneontology.org/60418ffa00001124"')
# Out:
#                                              gocam  \
# 62  http://model.geneontology.org/60418ffa00001124
# 62  http://model.geneontology.org/60418ffa00001124
#
#                                      title  \
# 62  Hypoxanthine catabolic process (Mouse)
# 62  Hypoxanthine catabolic process (Mouse)
#
#                                identifier
# 62  http://identifiers.org/uniprot/P47989
# 62  http://identifiers.org/uniprot/A6NGE7

# %%
#There are 4 models in the reactome file that don't appear to be actually from reactome
data_reactome_cleaned = data_reactome[data_reactome['gocam'].apply(lambda x: '/R-' in x)]

# %% [markdown]
# The next two cells verify that all cases of uniprot IDs from the metabolic models tsv are from these 4 non-reactome gocams

# %%
data_reactome = data_reactome.explode('identifier')
data_reactome.reset_index(inplace=True)
data_reactome[data_reactome['gocam'].apply(lambda x: 'R-' not in x)]
# Out:
#       index                                           gocam  \
# 5315   1090  http://model.geneontology.org/596a6e0600000152
# 5316   1090  http://model.geneontology.org/596a6e0600000152
# 5317   1090  http://model.geneontology.org/596a6e0600000152
# 5318   1090  http://model.geneontology.org/596a6e0600000152
# 5319   1090  http://model.geneontology.org/596a6e0600000152
# 5320   1092  http://model.geneontology.org/613aae0000000061
# 5321   1092  http://model.geneontology.org/613aae0000000061
# 5322   1092  http://model.geneontology.org/613aae0000000061
# 5323   1092  http://model.geneontology.org/613aae0000000061
# 5324   1092  http://model.geneontology.org/613aae0000000061
# 5325   1092  http://model.geneontology.org/613aae0000000061
# 5326   1092  http://model.geneontology.org/613aae0000000061
# 5327   1092  http://model.geneontology.org/613aae0000000061
# 5328   1092  http://model.geneontology.org/613aae0000000061
# 5329   1092  http://model.geneontology.org/613aae0000000061
# 5330   1092  http://model.geneontology.org/613aae0000000061
# 5331   1092  http://model.geneontology.org/613aae0000000061
# 5332   1092  http://model.geneontology.org/613aae0000000061
# 5333   1095  http://model.geneontology.org/5a5fc23a00000008
# 5334   1095  http://model.geneontology.org/5a5fc23a00000008
# 5335   1095  http://model.geneontology.org/5a5fc23a00000008
# 5336   1095  http://model.geneontology.org/5a5fc23a00000008
# 5337   1097  http://model.geneontology.org/5970219a00000013
# 5338   1097  http://model.geneontology.org/5970219a00000013
# 5339   1097  http://model.geneontology.org/5970219a00000013
# 5340   1097  http://model.geneontology.org/5970219a00000013
# 5341   1097  http://model.geneontology.org/5970219a00000013
# 5342   1097  http://model.geneontology.org/5970219a00000013
#
#                                 title  \
# 5315                    GPI1_human_PD
# 5316                    GPI1_human_PD
# 5317                    GPI1_human_PD
# 5318                    GPI1_human_PD
# 5319                    GPI1_human_PD
# 5320               cGAS-STING (Human)
# 5321               cGAS-STING (Human)
# 5322               cGAS-STING (Human)
# 5323               cGAS-STING (Human)
# 5324               cGAS-STING (Human)
# 5325               cGAS-STING (Human)
# 5326               cGAS-STING (Human)
# 5327               cGAS-STING (Human)
# 5328               cGAS-STING (Human)
# 5329               cGAS-STING (Human)
# 5330               cGAS-STING (Human)
# 5331               cGAS-STING (Human)
# 5332               cGAS-STING (Human)
# 5333  adenylate cyclase test 20180123
# 5334  adenylate cyclase test 20180123
# 5335  adenylate cyclase test 20180123
# 5336  adenylate cyclase test 20180123
# 5337                    GPI2_human_PD
# 5338                    GPI2_human_PD
# 5339                    GPI2_human_PD
# 5340                    GPI2_human_PD
# 5341                    GPI2_human_PD
# 5342                    GPI2_human_PD
#
#                                      identifier
# 5315      http://identifiers.org/uniprot/Q9Y2B2
# 5316      http://identifiers.org/uniprot/Q7Z7B1
# 5317      http://identifiers.org/uniprot/P37287
# 5318      http://identifiers.org/uniprot/Q9H3S5
# 5319      http://identifiers.org/uniprot/O60762
# 5320      http://identifiers.org/uniprot/Q8N884
# 5321      http://identifiers.org/uniprot/Q86WV6
# 5322    http://identifiers.org/uniprot/Q92993-4
# 5323    http://identifiers.org/uniprot/Q9NSU2-3
# 5324    http://identifiers.org/uniprot/Q96GD4-1
# 5325    http://identifiers.org/uniprot/Q96GF1-1
# 5326      http://identifiers.org/uniprot/O75531
# 5327    http://identifiers.org/uniprot/P78527-1
# 5328      http://identifiers.org/uniprot/P31749
# 5329      http://identifiers.org/uniprot/P42574
# 5330      http://identifiers.org/uniprot/O00743
# 5331      http://identifiers.org/uniprot/Q9UHD2
# 5332      http://identifiers.org/uniprot/Q9BRZ2
# 5333      http://identifiers.org/uniprot/Q08828
# 5334    http://identifiers.org/uniprot/P13861-1
# 5335    http://identifiers.org/uniprot/P17612-1
# 5336      http://identifiers.org/uniprot/Q08493
# 5337      http://identifiers.org/uniprot/Q9H3S5
# 5338      http://identifiers.org/uniprot/O95427
# 5339      http://identifiers.org/uniprot/Q9NUD9
# 5340      http://identifiers.org/uniprot/Q92521
# 5341  http://purl.obolibrary.org/obo/GO_0032991
# 5342      http://identifiers.org/uniprot/Q86VD9

# %%
data_reactome[data_reactome['identifier'].apply(lambda x: 'uniprot' in x)]
# Out:
#       index                                           gocam  \
# 5315   1090  http://model.geneontology.org/596a6e0600000152
# 5316   1090  http://model.geneontology.org/596a6e0600000152
# 5317   1090  http://model.geneontology.org/596a6e0600000152
# 5318   1090  http://model.geneontology.org/596a6e0600000152
# 5319   1090  http://model.geneontology.org/596a6e0600000152
# 5320   1092  http://model.geneontology.org/613aae0000000061
# 5321   1092  http://model.geneontology.org/613aae0000000061
# 5322   1092  http://model.geneontology.org/613aae0000000061
# 5323   1092  http://model.geneontology.org/613aae0000000061
# 5324   1092  http://model.geneontology.org/613aae0000000061
# 5325   1092  http://model.geneontology.org/613aae0000000061
# 5326   1092  http://model.geneontology.org/613aae0000000061
# 5327   1092  http://model.geneontology.org/613aae0000000061
# 5328   1092  http://model.geneontology.org/613aae0000000061
# 5329   1092  http://model.geneontology.org/613aae0000000061
# 5330   1092  http://model.geneontology.org/613aae0000000061
# 5331   1092  http://model.geneontology.org/613aae0000000061
# 5332   1092  http://model.geneontology.org/613aae0000000061
# 5333   1095  http://model.geneontology.org/5a5fc23a00000008
# 5334   1095  http://model.geneontology.org/5a5fc23a00000008
# 5335   1095  http://model.geneontology.org/5a5fc23a00000008
# 5336   1095  http://model.geneontology.org/5a5fc23a00000008
# 5337   1097  http://model.geneontology.org/5970219a00000013
# 5338   1097  http://model.geneontology.org/5970219a00000013
# 5339   1097  http://model.geneontology.org/5970219a00000013
# 5340   1097  http://model.geneontology.org/5970219a00000013
# 5342   1097  http://model.geneontology.org/5970219a00000013
#
#                                 title                               identifier
# 5315                    GPI1_human_PD    http://identifiers.org/uniprot/Q9Y2B2
# 5316                    GPI1_human_PD    http://identifiers.org/uniprot/Q7Z7B1
# 5317                    GPI1_human_PD    http://identifiers.org/uniprot/P37287
# 5318                    GPI1_human_PD    http://identifiers.org/uniprot/Q9H3S5
# 5319                    GPI1_human_PD    http://identifiers.org/uniprot/O60762
# 5320               cGAS-STING (Human)    http://identifiers.org/uniprot/Q8N884
# 5321               cGAS-STING (Human)    http://identifiers.org/uniprot/Q86WV6
# 5322               cGAS-STING (Human)  http://identifiers.org/uniprot/Q92993-4
# 5323               cGAS-STING (Human)  http://identifiers.org/uniprot/Q9NSU2-3
# 5324               cGAS-STING (Human)  http://identifiers.org/uniprot/Q96GD4-1
# 5325               cGAS-STING (Human)  http://identifiers.org/uniprot/Q96GF1-1
# 5326               cGAS-STING (Human)    http://identifiers.org/uniprot/O75531
# 5327               cGAS-STING (Human)  http://identifiers.org/uniprot/P78527-1
# 5328               cGAS-STING (Human)    http://identifiers.org/uniprot/P31749
# 5329               cGAS-STING (Human)    http://identifiers.org/uniprot/P42574
# 5330               cGAS-STING (Human)    http://identifiers.org/uniprot/O00743
# 5331               cGAS-STING (Human)    http://identifiers.org/uniprot/Q9UHD2
# 5332               cGAS-STING (Human)    http://identifiers.org/uniprot/Q9BRZ2
# 5333  adenylate cyclase test 20180123    http://identifiers.org/uniprot/Q08828
# 5334  adenylate cyclase test 20180123  http://identifiers.org/uniprot/P13861-1
# 5335  adenylate cyclase test 20180123  http://identifiers.org/uniprot/P17612-1
# 5336  adenylate cyclase test 20180123    http://identifiers.org/uniprot/Q08493
# 5337                    GPI2_human_PD    http://identifiers.org/uniprot/Q9H3S5
# 5338                    GPI2_human_PD    http://identifiers.org/uniprot/O95427
# 5339                    GPI2_human_PD    http://identifiers.org/uniprot/Q9NUD9
# 5340                    GPI2_human_PD    http://identifiers.org/uniprot/Q92521
# 5342                    GPI2_human_PD    http://identifiers.org/uniprot/Q86VD9

# %%
#not used (utils.update_dict used instead... i think)
def build_dict (data): #data= dataframe with gocam IDs and gene identifiers as columns
    Dict = {}
    for index, row in data.iterrows():
        gene = row['identifier']
        gocam = row['gocam']
        if (gene in Dict) == False:
            Dict[gene]={gocam}
        else:
            prev = Dict.get(gene)
            prev.add(gocam)
            Dict[gene] = prev
    return Dict

# %%
uIDs = utils.csv2dict('../data/uIDs_f.csv')

# %%
#needed to update identifiers.csv after importing the new reactome models... dependence of the reactome2uniprot notebook on this line is bad
#data2matrix(data_reactome_cleaned).identifier.to_csv('../data/identifiers.csv')

# %%
#expand rows
data_reactome = data_reactome_cleaned.explode('identifier')
data_reactome.reset_index(inplace=True)
data_ = pd.concat([data_human.explode('identifier'),mouse_mgi])
data_.reset_index(inplace=True)

#data_reactome = data2matrix(data_reactome_cleaned)
#data_ = data2matrix(data)

#KEEP ONLY UNIPROT, GO COMPLEX
data_uniprot = data_[data_.identifier.apply(lambda x: 'uniprot' in x) ]
data_uniprot.identifier = data_uniprot.identifier.apply(lambda x: x.split('/')[-1])
data_GOcomplex = data_[data_.identifier.apply(lambda x: 'obo/GO_' in x) ]

#map IDs using uIDs dictionary
data_reactome['uniprot']=data_reactome['identifier'].apply(lambda x: uIDs.get(x,'NOT FOUND'))
num_before = len(data_reactome)
not_mapped = data_reactome[data_reactome['uniprot'] == 'NOT FOUND']
data_reactome = data_reactome[data_reactome['uniprot'] != 'NOT FOUND'] 
num_lost = num_before - len(data_reactome)
data_reactome['identifier'] = data_reactome['uniprot']
data_reactome = data_reactome.drop('uniprot',axis=1)
num_lost
# Out:
# /Users/nicholasmarkarian/opt/miniconda3/envs/gocam/lib/python3.7/site-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# 129

# %%
not_mapped.identifier.apply(lambda x: x.split('REACTO_')[-1]).unique()
# Out:
# array(['R-HSA-451336', 'R-HSA-2565924', 'R-HSA-8939790', 'R-HSA-8939797',
#        'R-HSA-2453687', 'R-HSA-2470277', 'R-HSA-5693080', 'R-HSA-175986',
#        'R-HSA-453132', 'R-HSA-5635063', 'R-HSA-8960083', 'R-CPE-9661715',
#        'R-CPE-9661737', 'R-HSA-9661701', 'R-HSA-9663470', 'R-HSA-2545205',
#        'R-HSA-974998', 'R-HSA-9604605', 'R-HSA-351835', 'R-HSA-5244779',
#        'R-HSA-2161915', 'R-HSA-9026899', 'R-HSA-9027561', 'R-HSA-9028288',
#        'R-HSA-9022670', 'R-HSA-2161751', 'R-HSA-9024779', 'R-HSA-9025025',
#        'R-HSA-8957350', 'R-HSA-9029001', 'R-HSA-428470', 'R-HSA-9027665',
#        'R-HSA-5250898', 'R-HSA-8853807', 'R-HSA-74731', 'R-HSA-74819',
#        'R-HSA-69593', 'R-HSA-8867341', 'R-HSA-8876883', 'R-ALL-72617',
#        'R-HSA-2869445', 'R-HSA-170641', 'R-HSA-71237', 'R-HSA-165022',
#        'R-HSA-70827', 'R-HSA-3076903', 'R-HSA-2167826', 'R-HSA-2167848',
#        'R-HSA-8953316', 'R-HSA-8953409', 'R-HSA-8953410', 'R-HSA-5661266',
#        'R-HSA-5490258', 'R-HSA-5359039', 'R-HSA-5357666', 'R-HSA-5359068',
#        'R-HSA-9693721', 'R-HSA-445025', 'R-HSA-4420020', 'R-HSA-380618',
#        'R-HSA-555063', 'R-HSA-9028348', 'R-HSA-390344', 'R-ALL-2529006',
#        'R-HSA-5359054', 'R-HSA-2465932', 'R-HSA-2465962', 'R-HSA-2466001',
#        'R-HSA-2161595', 'R-HSA-2161957', 'R-HSA-2161764', 'R-HSA-2161598',
#        'R-HSA-2161674', 'R-HSA-3159312', 'R-HSA-1678773', 'R-HSA-2247521',
#        'R-HSA-1630327', 'R-HSA-1793214', 'R-HSA-997387', 'R-HSA-3076890',
#        'R-HSA-204704', 'R-HSA-177742', 'R-HSA-1655455', 'R-HSA-8939794'],
#       dtype=object)

# %%
data_reactome = data_reactome.explode('identifier')
data_reactome.reset_index(inplace=True)
data_reactome.title = data_reactome.title.apply(lambda x : x.replace("imported from: Reactome","Reactome"))
#data_reactome = data2matrix(data_reactome)

# %%
data_reactome[data_reactome.identifier.isna()]
# Out:
#        level_0  index                                        gocam  \
# 16507     4144    803  http://model.geneontology.org/R-HSA-3928662
# 16517     4148    804  http://model.geneontology.org/R-HSA-2682334
#
#                                             title identifier
# 16507  EPHB-mediated forward signaling - Reactome        NaN
# 16517             EPH-Ephrin signaling - Reactome        NaN

# %%
data_final = pd.concat([data_uniprot,data_reactome])
data_final = data_final[['gocam','title','identifier']]
data_final = data_final.drop_duplicates()
data_final = data_final.dropna()
data_final.identifier = data_final.identifier.apply(lambda x: x.split('/')[-1])
data_final.to_csv('../data/data_final_mouse_ff.csv')
modelID2title = pd.Series(data_final.title.values,index=data_final.gocam)
modelID2title.to_csv('../data/modelID2title_mouse.csv')
data_final
# Out:
#                                                 gocam  \
# 0      http://model.geneontology.org/627d95ee00000024
# 1      http://model.geneontology.org/627d95ee00000024
# 2      http://model.geneontology.org/627d95ee00000024
# 3      http://model.geneontology.org/627d95ee00000024
# 4      http://model.geneontology.org/627d95ee00000024
# ...                                               ...
# 20212      http://model.geneontology.org/R-HSA-110312
# 20213      http://model.geneontology.org/R-HSA-110312
# 20214      http://model.geneontology.org/R-HSA-110312
# 20215      http://model.geneontology.org/R-HSA-110312
# 20216      http://model.geneontology.org/R-HSA-110312
#
#                                           title identifier
# 0       IL12-mediated signaling pathway (Human)     P29597
# 1       IL12-mediated signaling pathway (Human)     Q14765
# 2       IL12-mediated signaling pathway (Human)     P29459
# 3       IL12-mediated signaling pathway (Human)     P29460
# 4       IL12-mediated signaling pathway (Human)     P42701
# ...                                         ...        ...
# 20212  Translesion synthesis by REV1 - Reactome     O60673
# 20213  Translesion synthesis by REV1 - Reactome     Q9UI95
# 20214  Translesion synthesis by REV1 - Reactome     Q9NS91
# 20215  Translesion synthesis by REV1 - Reactome     P63146
# 20216  Translesion synthesis by REV1 - Reactome     Q9UBZ9
#
# [18127 rows x 3 columns]

# %%
len(data_final[data_final.title.apply(lambda x: ('mouse' in x) or ('Mouse' in x))].title.unique())
# Out:
# 76

# %%
D = {}
D = utils.update_dict(D, data_final[['gocam','identifier']],'identifier','gocam')
x = []
for key in D:
    num_gocams = len(D.get(key))
    x.append(num_gocams)
plt.hist(x, bins=15, range=(0,15))
plt.xlabel("number of gocams")
plt.ylabel("number of genes")
plt.title("DEV ENDPOINT: number of gocams each gene is involved in")
plt.xticks(np.arange(0,15))
# Out:
# ([<matplotlib.axis.XTick at 0x7fc71260a5d0>,
#   <matplotlib.axis.XTick at 0x7fc71260a610>,
#   <matplotlib.axis.XTick at 0x7fc71260aa50>,
#   <matplotlib.axis.XTick at 0x7fc7118b03d0>,
#   <matplotlib.axis.XTick at 0x7fc7118b0390>,
#   <matplotlib.axis.XTick at 0x7fc7118b29d0>,
#   <matplotlib.axis.XTick at 0x7fc7118b2390>,
#   <matplotlib.axis.XTick at 0x7fc7118b3c90>,
#   <matplotlib.axis.XTick at 0x7fc7118b3750>,
#   <matplotlib.axis.XTick at 0x7fc7118b31d0>,
#   <matplotlib.axis.XTick at 0x7fc7118b8c90>,
#   <matplotlib.axis.XTick at 0x7fc7118b8550>,
#   <matplotlib.axis.XTick at 0x7fc7118bafd0>,
#   <matplotlib.axis.XTick at 0x7fc7118b8d50>,
#   <matplotlib.axis.XTick at 0x7fc7118b3690>],
#  <a list of 15 Text major ticklabel objects>)

# %%
def get_sizes (data): #data= dataframe with gocam IDs and gene identifiers as columns
    return data['gocam'].value_counts()

# %%
def filter_gene_list(gene_list, Dict):
    filtered_gene_list = []
    for gene in gene_list:
        if gene in Dict:
            filtered_gene_list.append(gene)
    return filtered_gene_list

# %%
def count_genes(gene_list, Dict):
    gocam_counts = {} #key=gocam, value=list of genes in gocam that are also in the user's list
    for g in gene_list: 
            gocams = Dict.get(g)
            for gocam in gocams:
                if (gocam in gocam_counts) == False:
                    gocam_counts[gocam]=[g]
                else:
                    prev = gocam_counts.get(gocam)
                    prev.append(g)
                    gocam_counts[gocam] = prev
    return gocam_counts

# %%
# APPLY BENJAMINI HOCHBERG CORRECTION in correct_pval_and_format()
def hgt(counts, gocam_sizes, FDR, gene_list_size, background_gene_list_size):
    results = []
    for gocam, gene_list in counts.items():
        count = len(gene_list) 
        gocam_size = gocam_sizes[gocam]
        pvalue = hypergeom.sf(count-1, background_gene_list_size,  gocam_size, gene_list_size) 
        if pvalue < FDR:
            r = (gocam, pvalue, count, gocam_size, gene_list )
            results.append(r)
    return results

# %%
def fdr(rank,num_tests,FDR):
    return (rank*FDR/num_tests)

# %%
#Benjamini Hochberg correction
def correct_pval_and_format(enriched_gocams, background_num_gocams):
    df = pd.DataFrame(enriched_gocams, columns =['Name', 'pval (uncorrected)', '# genes in list','#genes in gocam','shared genes in gocam'])
    df.sort_values('pval (uncorrected)',inplace=True)
    df.reset_index(drop=True, inplace=True)
    df['FDR_val'] = (df.index+1)*.05/background_num_gocams
    df['Less_than'] = (df['pval (uncorrected)'] < df['FDR_val'])
    index = df.Less_than.where(df.Less_than==True).last_valid_index()
    df_significant = df.loc[0:index]
    df_display = df_significant[['Name','pval (uncorrected)', '# genes in list', '#genes in gocam','shared genes in gocam']]
    return(df_display)

# %%
#as of now, Dict can only contain 1 instance of each gene per gocam (no duplicates)
#SURVIVAL FUNCTION, NOT PMF
def enrich(gene_list,gocam_sizes, Dict):
    background_gene_list_size = len(Dict)
    gene_list_filtered = filter_gene_list(gene_list, Dict) #need to clean gene_list to only include genes in the gocam
    gene_list_size = len(gene_list_filtered) #the size of the user's gene list AFTER filtering
    counts = count_genes(gene_list_filtered, Dict)
    enriched_gocams = hgt(counts, gocam_sizes, .05, gene_list_size, background_gene_list_size)
    background_num_gocams = len(gocam_sizes)
    df_display = correct_pval_and_format(enriched_gocams, background_num_gocams)
    return gene_list_filtered, df_display

# %%
gocam_sizes = get_sizes(data_final)
gocam_sizes.to_csv('../data/gocam_sizes_mouse_ff.csv',header=['sizes'],index_label='gocam')
Dict = {}
Dict = utils.update_dict(Dict, data_final, 'identifier','gocam')
utils.dict2csv(Dict,'../data/ID2gocam_mouse_ff.csv')

# %% [markdown]
# genes = pd.DataFrame( {'g':mouse_mgi.identifier})
# species = 'mouse'
# genes.g = genes.g.str.upper()
# input_type = 'Gene ID' #MGI
#
# no_ortho = []
# if species == 'mouse':
#     file = '../data/simplemine_results_mouse.txt'
#     table = pd.read_csv(file,sep='\t', header=3)
#     d= pd.Series(table['Human Ortholog'].values,index=table[input_type]).to_dict()
#     genes['mouse']=genes['g']
#     genes['g']=genes['g'].apply(lambda x: d.get(x,'NO ORTHOLOG FOUND')) #human orthologs as HGNC
#     no_ortho = genes[genes.g == 'NO ORTHOLOG FOUND']
#     genes = genes[genes.g != 'NO ORTHOLOG FOUND']
#     input_type = 'Gene ID' #new input type for the subsequent human HGNC->uniprot mapping
