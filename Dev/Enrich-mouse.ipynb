# %%
# !date
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats
from scipy.stats import hypergeom
import sys
sys.path.append('../GOCAM_Project/dev')

import utils
import enrich

pd.options.display.max_colwidth = 100
# Out:
# Thu Oct 27 18:20:34 PDT 2022

# %%
table = pd.read_csv('../data/simplemine_results.txt',sep='\t', header=3)
table[table['Gene ID'] == "HGNC:5715"]
# Out:
#       Your Input    Gene ID Gene Symbol                   Gene Name  \
# 38417  HGNC:5715  HGNC:5715         IGK  immunoglobulin kappa locus
#
#             Species NCBI ID ENSEMBL ID UniProtKB ID PANTHER ID  \
# 38417  Homo sapiens   50802       N.A.         N.A.       N.A.
#
#                                                                   Synonym  \
# 38417  IGK@ | MGC22645 | MGC71990 | MGC27376 | FLJ26296 | IGKC | MGC40426
#
#       Mouse Ortholog
# 38417           N.A.

# %% [markdown]
# # Enrichment examples

# %%
gene_list = pd.read_csv('../../Desktop/GOCAM/cancer.csv',header=None,names = ['g'])
cancer_test_set, uniprot2input, not_converted = utils.convert_IDs(gene_list,'Gene Symbol')
x = pd.read_csv('../data/gocam_sizes_mouse.csv')
gocam_sizes = pd.Series(x.sizes.values,index=x.gocam)
Dict = utils.csv2dict('../data/ID2gocam_mouse.csv')
filtered_out_genes, filtered_list, setID2members_input_uni, setID2members_input, df_display= enrich.enrich(list(gene_list.g), cancer_test_set, uniprot2input, gocam_sizes, Dict, alpha = .05)
df_display#[df_display.title.apply(lambda x: 'Reactome' not in x)]
# Out:
#                                                        title  \
# 0   Role of LAT2/NTAL/LAB on calcium mobilization - Reactome
# 1               CD28 dependent PI3K/Akt signaling - Reactome
# 2                                 DAP12 signaling - Reactome
# 3                  Downstream signal transduction - Reactome
# 4           VEGFR2 mediated vascular permeability - Reactome
# 5     Negative regulation of the PI3K/AKT network - Reactome
# 6                            Stabilization of p53 - Reactome
# 7                GPVI-mediated activation cascade - Reactome
# 8                     Oncogene Induced Senescence - Reactome
# 9                       MAP2K and MAPK activation - Reactome
# 10                             PI3K/AKT Signaling - Reactome
# 11      G beta:gamma signalling through PI3Kgamma - Reactome
# 12                                 PD-1 signaling - Reactome
# 13                        Dual incision in TC-NER - Reactome
# 14                 Regulation of TP53 Degradation - Reactome
# 15                            PI3K/AKT activation - Reactome
# 16                PLCG1 events in ERBB2 signaling - Reactome
# 17                           Signaling by SCF-KIT - Reactome
# 18                  ERBB2 Regulates Cell Motility - Reactome
# 19                               GAB1 signalosome - Reactome
# 20                 PI3K events in ERBB2 signaling - Reactome
# 21       Synthesis of PIPs at the plasma membrane - Reactome
# 22          Role of phospholipids in phagocytosis - Reactome
#
#     pval (uncorrected)  # genes in list  #genes in gocam  \
# 0         1.590968e-07                6                7
# 1         5.812643e-07                8               16
# 2         6.076063e-07                6                8
# 3         4.154641e-06                6               10
# 4         4.705982e-06                8               20
# 5         8.610631e-06                5                7
# 6         8.727819e-06                6               11
# 7         1.589086e-05                8               23
# 8         4.032287e-05                4                5
# 9         4.720971e-05                5                9
# 10        7.863839e-05                6               15
# 11        9.026477e-05                5               10
# 12        1.573991e-04                3                3
# 13        2.587681e-04                4                7
# 14        2.600137e-04                7               25
# 15        4.955871e-04                4                8
# 16        4.955871e-04                4                8
# 17        5.993024e-04                5               14
# 18        6.043255e-04                3                4
# 19        6.043255e-04                3                4
# 20        6.474722e-04                6               21
# 21        6.474722e-04                6               21
# 22        8.504878e-04                6               22
#
#                                                                           shared gene products in gocam  \
# 0   [P42336, P43405, sset:PI3K-regulatory subunit, sset:PI3K-catalytic subunit, sset:SYK/FYN, sset:S...
# 1   [P42336, P27986, sset:PI3K alpha, beta, gamma, sset:PI3K-regulatory subunit, sset:PI3K-catalytic...
# 2   [P43405, sset:PI3K-regulatory subunit, sset:PI3K-catalytic subunit, sset:p-SYK,p-BTK, sset:FYN,L...
# 3   [P01127, P16234, P09619, P42336, sset:Phospho- PDGF receptor dimer, sset:Active PDGF dimers (AA,...
# 4   [P31749, P42336, P27986, P07900, sset:PI3K alpha, beta, gamma, sset:PI3K-regulatory subunit, sse...
# 5   [P60484, sset:PI3K-regulatory subunit, sset:PI3K-catalytic subunit, sset:Activator:PI3K, sset:PI...
# 6          [Q13315, O96017, Q00987, O15151, P04637, sset:p-S166,S188-MDM2 dimer, p-S166,S188-MDM2:MDM4]
# 7   [P42336, P27986, P43405, sset:PI3K alpha, beta, gamma, sset:PI3K-regulatory subunit, sset:PI3K-c...
# 8   [Q00987, P04637, sset:p-T172-CDK4,p-T177-CDK6:CCND:CDKN1A,CDKN1B,(CDKN1C); p-T172-CDK4,p-T177-CD...
# 9   [sset:RAF/MAPK scaffolds, sset:RAF activating kinases, sset:'activator' RAFs, sset:mature p21 RA...
# 10  [P42336, P27986, sset:PI3K alpha, beta, gamma, sset:PI3K-regulatory subunit, sset:PI3K-catalytic...
# 11  [P42336, P27986, sset:PI3K alpha, beta, gamma, sset:PI3K-regulatory subunit, sset:PI3K-catalytic...
# 12                                                              [P06239, sset:SHP1,SHP2, sset:LCK, CSK]
# 13                                                                     [P18074, P19447, Q92889, P28715]
# 14  [Q13315, O96017, Q00987, O15151, P04637, sset:p-S166,S188-MDM2 dimer, p-S166,S188-MDM2:MDM4, sse...
# 15                          [P04629, P60484, sset:PI3K-regulatory subunit, sset:PI3K-catalytic subunit]
# 16                            [P00533, P04626, sset:p-Y877-ERBB2 heterodimers, sset:ERBB2 heterodimers]
# 17  [O60674, P10721, sset:PI3K-regulatory subunit, sset:PI3K-catalytic subunit, sset:Src family tyro...
# 18                                    [P04626, sset:p-Y877-ERBB2 heterodimers, sset:ERBB2 heterodimers]
# 19                                                                             [P00533, P42336, Q06124]
# 20            [P00533, P04626, P42336, P27986, sset:p-Y877-ERBB2 heterodimers, sset:ERBB2 heterodimers]
# 21  [P60484, sset:PI3K-regulatory subunit, sset:PI3K-catalytic subunit, sset:Activator:PI3K, sset:PI...
# 22  [P60484, P43405, sset:PI3K-regulatory subunit, sset:PI3K-catalytic subunit, sset:G-protein alpha...
#
#                                             url
# 0   http://model.geneontology.org/R-HSA-2730905
# 1    http://model.geneontology.org/R-HSA-389357
# 2   http://model.geneontology.org/R-HSA-2424491
# 3    http://model.geneontology.org/R-HSA-186763
# 4   http://model.geneontology.org/R-HSA-5218920
# 5    http://model.geneontology.org/R-HSA-199418
# 6     http://model.geneontology.org/R-HSA-69541
# 7    http://model.geneontology.org/R-HSA-114604
# 8   http://model.geneontology.org/R-HSA-2559585
# 9   http://model.geneontology.org/R-HSA-5674135
# 10  http://model.geneontology.org/R-HSA-1257604
# 11   http://model.geneontology.org/R-HSA-392451
# 12   http://model.geneontology.org/R-HSA-389948
# 13  http://model.geneontology.org/R-HSA-6782135
# 14  http://model.geneontology.org/R-HSA-6804757
# 15   http://model.geneontology.org/R-HSA-198203
# 16  http://model.geneontology.org/R-HSA-1251932
# 17  http://model.geneontology.org/R-HSA-1433557
# 18  http://model.geneontology.org/R-HSA-6785631
# 19   http://model.geneontology.org/R-HSA-180292
# 20  http://model.geneontology.org/R-HSA-1963642
# 21  http://model.geneontology.org/R-HSA-1660499
# 22  http://model.geneontology.org/R-HSA-2029485

# %%
len(gene_list.g),len(filtered_list), len(filtered_out_genes)
# Out:
# (412, 216, 270)

# %%
gene_list = pd.read_csv('../../Desktop/GOCAM/gastric_cancer.csv',header=None,names = ['g'])
cancer_test_set, uniprot2input, not_converted = utils.convert_IDs(gene_list,'ENSEMBL ID')
x = pd.read_csv('../data/gocam_sizes_mouse.csv')
gocam_sizes = pd.Series(x.sizes.values,index=x.gocam)
Dict = utils.csv2dict('../data/ID2gocam_mouse.csv')
filtered_out_genes, filtered_list, setID2members_input_uni, setID2members_input, df_display= enrich.enrich(list(gene_list.g), cancer_test_set, uniprot2input, gocam_sizes, Dict,alpha=.05)
df_display#[df_display.title.apply(lambda x: 'Interleukin' in x)]
# Out:
#                                                                 title  \
# 0                           SHC1 events in ERBB2 signaling - Reactome
# 1              Negative regulation of the PI3K/AKT network - Reactome
# 2                          PLCG1 events in ERBB2 signaling - Reactome
# 3                                MAP2K and MAPK activation - Reactome
# 4                            ERBB2 Regulates Cell Motility - Reactome
# 5                           Downstream signal transduction - Reactome
# 6                 Synthesis of PIPs at the plasma membrane - Reactome
# 7                           PI3K events in ERBB2 signaling - Reactome
# 8                                       Signaling by ERBB2 - Reactome
# 9                           ERBB2 Activates PTK6 Signaling - Reactome
# 10                                          BMP2-MAPK signaling mouse
# 11                                      PI3K/AKT Signaling - Reactome
# 12  Sema4D induced cell migration and growth-cone collapse - Reactome
# 13                       CD28 dependent PI3K/Akt signaling - Reactome
#
#     pval (uncorrected)  # genes in list  #genes in gocam  \
# 0             0.000009                5               13
# 1             0.000011                4                7
# 2             0.000022                4                8
# 3             0.000040                4                9
# 4             0.000057                3                4
# 5             0.000065                4               10
# 6             0.000121                5               21
# 7             0.000121                5               21
# 8             0.000139                3                5
# 9             0.000139                3                5
# 10            0.000208                4               13
# 11            0.000382                4               15
# 12            0.000471                3                7
# 13            0.000500                4               16
#
#                                                                           shared gene products in gocam  \
# 0   [P04626, sset:ERBB2 heterodimers, sset:p-Y877-ERBB2 heterodimers, sset:p-ERBB2 heterodimers, sse...
# 1                             [P60484, sset:Activator:PI3K, sset:PI3K-catalytic subunit, sset:PIK3C(1)]
# 2                             [P04626, P00533, sset:ERBB2 heterodimers, sset:p-Y877-ERBB2 heterodimers]
# 3    [sset:activated RAF/KSR1, sset:RAF activating kinases, sset:'activator' RAFs, sset:mature p21 RAS]
# 4                                     [P04626, sset:ERBB2 heterodimers, sset:p-Y877-ERBB2 heterodimers]
# 5                                           [P42336, P09619, P16234, sset:Phospho- PDGF receptor dimer]
# 6               [P60484, sset:Activator:PI3K, sset:PI3K-catalytic subunit, sset:PIK3C(1), sset:PIK3(2)]
# 7                     [P04626, P42336, P00533, sset:ERBB2 heterodimers, sset:p-Y877-ERBB2 heterodimers]
# 8                                     [P04626, sset:ERBB2 heterodimers, sset:p-Y877-ERBB2 heterodimers]
# 9                                     [P04626, sset:ERBB2 heterodimers, sset:p-Y877-ERBB2 heterodimers]
# 10                                                             [A0A1W2PPB5, A0A024RD15, B5BUG9, O00238]
# 11             [P42336, sset:PI3K alpha, beta, gamma, sset:Activator:PI3K, sset:PI3K-catalytic subunit]
# 12                                                                [P04626, sset:GEFs, sset:ROCK1,ROCK2]
# 13             [P42336, sset:PI3K alpha, beta, gamma, sset:Activator:PI3K, sset:PI3K-catalytic subunit]
#
#                                                url
# 0      http://model.geneontology.org/R-HSA-1250196
# 1       http://model.geneontology.org/R-HSA-199418
# 2      http://model.geneontology.org/R-HSA-1251932
# 3      http://model.geneontology.org/R-HSA-5674135
# 4      http://model.geneontology.org/R-HSA-6785631
# 5       http://model.geneontology.org/R-HSA-186763
# 6      http://model.geneontology.org/R-HSA-1660499
# 7      http://model.geneontology.org/R-HSA-1963642
# 8      http://model.geneontology.org/R-HSA-1227986
# 9      http://model.geneontology.org/R-HSA-8847993
# 10  http://model.geneontology.org/5fce9b7300000434
# 11     http://model.geneontology.org/R-HSA-1257604
# 12      http://model.geneontology.org/R-HSA-416572
# 13      http://model.geneontology.org/R-HSA-389357

# %%
len(gene_list.g),len(filtered_out_genes)
# Out:
# (100, 55)

# %%
gene_list = pd.read_csv('../../Desktop/GOCAM/bladder_cancer.csv',header=None,names = ['g'])
cancer_test_set, uniprot2input, not_converted = utils.convert_IDs(gene_list,'ENSEMBL ID')
x = pd.read_csv('../data/gocam_sizes_mouse.csv')
gocam_sizes = pd.Series(x.sizes.values,index=x.gocam)
Dict = utils.csv2dict('../data/ID2gocam_mouse.csv')
filtered_out_genes, filtered_list, setID2members_input_uni, setID2members_input, df_display= enrich.enrich(list(gene_list.g), cancer_test_set, uniprot2input, gocam_sizes, Dict, alpha = .05)
df_display#[df_display.title.apply(lambda x: 'Reactome' not in x)]
# Out:
#                                                          title  \
# 0       Negative regulation of the PI3K/AKT network - Reactome
# 1          Synthesis of PIPs at the plasma membrane - Reactome
# 2                                PI3K/AKT Signaling - Reactome
# 3                 CD28 dependent PI3K/Akt signaling - Reactome
# 4             VEGFR2 mediated vascular permeability - Reactome
# 5                   PLCG1 events in ERBB2 signaling - Reactome
# 6                    PI3K events in ERBB2 signaling - Reactome
# 7                                 RHOA GTPase cycle - Reactome
# 8                                 RHOC GTPase cycle - Reactome
# 9                                 RHOB GTPase cycle - Reactome
# 10                               CDC42 GTPase cycle - Reactome
# 11                                RAC2 GTPase cycle - Reactome
# 12                                RAC1 GTPase cycle - Reactome
# 13                 GPVI-mediated activation cascade - Reactome
# 14        G beta:gamma signalling through PI3Kgamma - Reactome
# 15                   SHC1 events in ERBB2 signaling - Reactome
# 16  PI5P, PP2A and IER3 Regulate PI3K/AKT Signaling - Reactome
#
#     pval (uncorrected)  # genes in list  #genes in gocam  \
# 0         9.501759e-07                4                7
# 1         5.962310e-06                5               21
# 2         3.423873e-05                4               15
# 3         4.520293e-05                4               16
# 4         1.156751e-04                4               20
# 5         1.189035e-04                3                8
# 6         1.414898e-04                4               21
# 7         1.737671e-04                2                2
# 8         1.737671e-04                2                2
# 9         1.737671e-04                2                2
# 10        1.737671e-04                2                2
# 11        1.737671e-04                2                2
# 12        1.737671e-04                2                2
# 13        2.052498e-04                4               23
# 14        2.500260e-04                3               10
# 15        5.792680e-04                3               13
# 16        5.792680e-04                3               13
#
#                                                                shared gene products in gocam  \
# 0                  [P60484, sset:Activator:PI3K, sset:PI3K-catalytic subunit, sset:PIK3C(1)]
# 1    [P60484, sset:Activator:PI3K, sset:PI3K-catalytic subunit, sset:PIK3C(1), sset:PIK3(2)]
# 2   [P42336, sset:PI3K alpha, beta, gamma, sset:Activator:PI3K, sset:PI3K-catalytic subunit]
# 3   [P42336, sset:PI3K alpha, beta, gamma, sset:Activator:PI3K, sset:PI3K-catalytic subunit]
# 4   [P42336, sset:PI3K alpha, beta, gamma, sset:Activator:PI3K, sset:PI3K-catalytic subunit]
# 5                          [P00533, sset:ERBB2 heterodimers, sset:p-Y877-ERBB2 heterodimers]
# 6                  [P42336, P00533, sset:ERBB2 heterodimers, sset:p-Y877-ERBB2 heterodimers]
# 7                                                           [sset:RHOA GEFs, sset:RHOA GAPs]
# 8                                                           [sset:RHOC GAPs, sset:RHOC GEFs]
# 9                                                           [sset:RHOB GAPs, sset:RHOB GEFs]
# 10                                                        [sset:CDC42 GAPs, sset:CDC42 GEFs]
# 11                                                          [sset:RAC2 GEFs, sset:RAC2 GAPs]
# 12                                                          [sset:RAC1 GEFs, sset:RAC1 GAPs]
# 13  [P42336, sset:PI3K alpha, beta, gamma, sset:Activator:PI3K, sset:PI3K-catalytic subunit]
# 14                       [P42336, sset:PI3K alpha, beta, gamma, sset:PI3K-catalytic subunit]
# 15      [sset:ERBB2 heterodimers, sset:p-ERBB2 heterodimers, sset:p-Y877-ERBB2 heterodimers]
# 16                           [P60484, sset:Activator:PI3K, sset:Activated SRC,LCK,EGFR,INSR]
#
#                                             url
# 0    http://model.geneontology.org/R-HSA-199418
# 1   http://model.geneontology.org/R-HSA-1660499
# 2   http://model.geneontology.org/R-HSA-1257604
# 3    http://model.geneontology.org/R-HSA-389357
# 4   http://model.geneontology.org/R-HSA-5218920
# 5   http://model.geneontology.org/R-HSA-1251932
# 6   http://model.geneontology.org/R-HSA-1963642
# 7   http://model.geneontology.org/R-HSA-8980692
# 8   http://model.geneontology.org/R-HSA-9013106
# 9   http://model.geneontology.org/R-HSA-9013026
# 10  http://model.geneontology.org/R-HSA-9013148
# 11  http://model.geneontology.org/R-HSA-9013404
# 12  http://model.geneontology.org/R-HSA-9013149
# 13   http://model.geneontology.org/R-HSA-114604
# 14   http://model.geneontology.org/R-HSA-392451
# 15  http://model.geneontology.org/R-HSA-1250196
# 16  http://model.geneontology.org/R-HSA-6811558

# %%
len(gene_list.g),len(filtered_out_genes)
# Out:
# (63, 35)

# %%
gene_list = pd.read_csv('../../Desktop/GOCAM/parkinson.csv',header=None,names = ['g'])
cancer_test_set, uniprot2input, not_converted = utils.convert_IDs(gene_list,'Gene Symbol')
x = pd.read_csv('../data/gocam_sizes_mouse.csv')
gocam_sizes = pd.Series(x.sizes.values,index=x.gocam)
Dict = utils.csv2dict('../data/ID2gocam_mouse.csv')
filtered_out_genes, filtered_list, setID2members_input_uni, setID2members_input, df_display= enrich.enrich(list(gene_list.g), cancer_test_set, uniprot2input, gocam_sizes, Dict, alpha=.05)
df_display#[df_display.title.apply(lambda x: 'Reactome' not in x)]
# Out:
#                                                                                  title  \
# 0                                                      Josephin domain DUBs - Reactome
# 1  Biogenic amines are oxidatively deaminated to aldehydes by MAOA and MAOB - Reactome
# 2                                                               Methylation - Reactome
# 3                                                   Glutathione conjugation - Reactome
# 4                 Synthesis of (16-20)-hydroxyeicosatetraenoic acids (HETE) - Reactome
# 5                                   Phospholipase C-mediated cascade; FGFR3 - Reactome
#
#    pval (uncorrected)  # genes in list  #genes in gocam  \
# 0            0.000010                3                3
# 1            0.000010                3                3
# 2            0.000022                5               17
# 3            0.000025                4                9
# 4            0.000040                3                4
# 5            0.000192                3                6
#
#                                                               shared gene products in gocam  \
# 0                                           [P54252, O60260, sset:ATXN3,ATXN3L,JOSD1,JOSD2]
# 1                                                                  [P27338, P21397, P31645]
# 2                                                  [P21964, P42898, P78417, P05177, Q99707]
# 3  [P04798, sset:GST dimers, sset:Cytochrome P450 (CYP2E1 based), sset:CYP1A2,3A4,3A5,2A13]
# 4                                                   [sset:CYP(2), sset:CYP(3), sset:CYP(1)]
# 5                [sset:FGFR3b-binding FGFs, sset:FGFR3c-binding FGFs, sset:Activated FGFR3]
#
#                                            url
# 0  http://model.geneontology.org/R-HSA-5689877
# 1   http://model.geneontology.org/R-HSA-141333
# 2   http://model.geneontology.org/R-HSA-156581
# 3   http://model.geneontology.org/R-HSA-156590
# 4  http://model.geneontology.org/R-HSA-2142816
# 5  http://model.geneontology.org/R-HSA-5654227

# %%
len(gene_list.g),len(filtered_out_genes)
# Out:
# (126, 64)

# %% [markdown]
# To Do:
# 1. cell type from atlas
# 2. RNAseq reponse to a substance like a toxin
# 3. think about the gene list size
# 4. make sure its just human genes, or if it's mouse, consider that
# 5. height gwas
# 6. make sure uniprot IDs are actually entered correctly
# 7. Tsui Fen

# %%
gene_list = pd.read_csv('../../Desktop/GOCAM/P97.csv',header=None,names = ['g'])
P97_test_set = gene_list.g
uniprot2input = pd.Series(P97_test_set.values,index=P97_test_set).to_dict()
x = pd.read_csv('../data/gocam_sizes_mouse.csv')
gocam_sizes = pd.Series(x.sizes.values,index=x.gocam)
Dict = utils.csv2dict('../data/ID2gocam_mouse.csv')
filtered_out_genes, filtered_list, setID2members_input_uni, setID2members_input, df_display= enrich.enrich(list(gene_list.g), P97_test_set, uniprot2input, gocam_sizes, Dict,alpha = .05)
df_display#[df_display.title.apply(lambda x: 'Hedgehog' in x)]
# Out:
#                                                         title  \
# 0  PI5P, PP2A and IER3 Regulate PI3K/AKT Signaling - Reactome
# 1                                 Unwinding of DNA - Reactome
#
#    pval (uncorrected)  # genes in list  #genes in gocam  \
# 0            0.000002                8               13
# 1            0.000002                6                7
#
#                                                                          shared gene products in gocam  \
# 0  [sset:PI4K2A/2B, sset:Activated SRC,LCK,EGFR,INSR, sset:PP2A-subunit A, sset:Activator:PI3K, sse...
# 1                                                     [P25205, Q14566, P33991, P49736, P33993, P33992]
#
#                                            url
# 0  http://model.geneontology.org/R-HSA-6811558
# 1   http://model.geneontology.org/R-HSA-176974

# %%
list_ = []
setID2members = utils.csv2dict('../data/setID2members.csv')
for i in df_display.loc[0,:]['shared gene products in gocam']:
    list_.append(len(setID2members.get(i)))
list_
# Out:
# [2, 6, 2, 86, 7, 2, 3, 2]

# %%
df_display.loc[0,:]['shared gene products in gocam']
# Out:
# ['sset:PI4K2A/2B',
#  'sset:Activated SRC,LCK,EGFR,INSR',
#  'sset:PP2A-subunit A',
#  'sset:Activator:PI3K',
#  'sset:SYNJ/MTM(1)',
#  'sset:PIP5K1A/B',
#  'sset:PIP5K1A-C',
#  'sset:PP2A-catalytic subunit C']

# %%
setID2members.get('sset:Activator:PI3K')
# Out:
# ['O00329',
#  'P35568',
#  'Q9Y4H2',
#  'P33681',
#  'P21802-18',
#  'P03372',
#  'O14944',
#  'Q99075',
#  'P11487',
#  'P14210',
#  'P03372-4',
#  'P08620',
#  'P62993-1',
#  'P21802-3',
#  'P04626',
#  'O60258-1',
#  'O76093',
#  'O43320',
#  'Q86Z14',
#  'Q02297-10',
#  'O00459',
#  'P22607-2',
#  'Q92569',
#  'O43815',
#  'P42336',
#  'P84095',
#  'Q8WU20',
#  'P12931',
#  'P35070',
#  'O14511',
#  'P55075-1',
#  'P09619',
#  'P08581',
#  'Q6PIZ9',
#  'P27986',
#  'Q92731',
#  'Q6ZUJ8',
#  'Q9NP95',
#  'P10721',
#  'P01133',
#  'Q9UEF7-2',
#  'Q9UEF7-1',
#  'P21781',
#  'O95750',
#  'P22455',
#  'P11362-19',
#  'O15520',
#  'P56975',
#  'P21802-5',
#  'P31371',
#  'Q9Y6W8-1',
#  'P01127',
#  'P09038',
#  'P49771',
#  'Q9GZV9',
#  'Q13480',
#  'P05230',
#  'Q15303-2',
#  'P42338',
#  'P15498',
#  'P16234',
#  'P00533',
#  'P42081',
#  'P06239',
#  'P22607-1',
#  'P21860-1',
#  'P06241',
#  'Q9UQC2',
#  'P63000',
#  'P10747',
#  'P21583-1',
#  'Q8WWG1',
#  'P04085-2',
#  'P11362-1',
#  'P15153',
#  'P03372-3',
#  'P04085-1',
#  'Q9HCT0',
#  'Q06124',
#  'P36888',
#  'Q02297',
#  'P15391',
#  'P12034-1',
#  'P10767',
#  'P21802-1',
#  'Q15303-1']

# %%
len(gene_list.g),len(filtered_list),len(filtered_out_genes)
# Out:
# (766, 338, 496)

# %%
#fully flattened vs set for PI5P, PP2A and IER3 Regulate PI3K/AKT Signaling - Reactome in P97 dataset 
#hypergeom.sf(count-1, background_gene_list_size,  gocam_size, gene_list_size)
hypergeom.sf(8-1, 5386,  122, 270),hypergeom.sf(8-1, 4008,  13, 338)
# Out:
# (0.2673159657624832, 2.085287471110162e-06)

# %% [markdown]
# # Messing around with a brain cell atlas

# %%
#atlas_class_iso =pd.read_csv("/Volumes/NICK/Sternberg/class_DE_isoform.csv")
#atlas_class_iso['symbol?'] = atlas_class_iso.index_name.apply(lambda x: x.split('_')[1])
#atlas_class_GLUT_iso = atlas_class_iso[atlas_class_iso['index_name'].apply(lambda x: 'Glutamatergic' in x)]
#atlas_class_GABA_iso = atlas_class_iso[atlas_class_iso['index_name'].apply(lambda x: 'GABAergic' in x)]

# %%
#atlas_class_GLUT_iso['symbol?'].to_csv('../test_data/atlas_class_GLUT_iso.csv',index=False)
#atlas_class_GABA_iso['symbol?'].to_csv('../test_data/atlas_class_GABA_iso.csv',index=False)

# %%
atlas_class_GLUT_iso = pd.read_csv('../test_data/atlas_class_GLUT_iso.csv')
atlas_class_GABA_iso = pd.read_csv('../test_data/atlas_class_GABA_iso.csv')

# %%
gene_list = pd.DataFrame({'g':atlas_class_GLUT_iso['symbol?']})
test_set, uniprot2input, not_converted = utils.convert_IDs(gene_list,'Gene Symbol')
x = pd.read_csv('../data/gocam_sizes_mouse.csv')
gocam_sizes = pd.Series(x.sizes.values,index=x.gocam)
Dict = utils.csv2dict('../data/ID2gocam_mouse.csv')
filtered_out_genes, filtered_list, setID2members_input_uni, setID2members_input, df_display= enrich.enrich(list(gene_list.g), test_set, uniprot2input, gocam_sizes, Dict, alpha = .07)
df_display
# Out:
#                                              title  pval (uncorrected)  \
# 0  Mitochondrial translation initiation - Reactome            0.000102
# 1  Mitochondrial translation elongation - Reactome            0.000114
#
#    # genes in list  #genes in gocam     shared gene products in gocam  \
# 0                4               35  [O60783, P82930, Q9Y291, Q9NWT8]
# 1                4               36  [O60783, P82930, Q9Y291, Q9NWT8]
#
#                                            url
# 0  http://model.geneontology.org/R-HSA-5368286
# 1  http://model.geneontology.org/R-HSA-5389840

# %%
len(gene_list.g.drop_duplicates()),len(filtered_out_genes),len(filtered_list),len(not_converted)
# Out:
# (69, 46, 29, 4)

# %%
gene_list = pd.DataFrame({'g':atlas_class_GABA_iso['symbol?']})
test_set, uniprot2input, not_converted = utils.convert_IDs(gene_list,'Gene Symbol')
x = pd.read_csv('../data/gocam_sizes_mouse.csv')
gocam_sizes = pd.Series(x.sizes.values,index=x.gocam)
Dict = utils.csv2dict('../data/ID2gocam_mouse.csv')
filtered_out_genes, filtered_list, setID2members_input_uni, setID2members_input, df_display= enrich.enrich(list(gene_list.g), test_set, uniprot2input, gocam_sizes, Dict, alpha = .05)
df_display
# Out:
#                                           title  pval (uncorrected)  \
# 0           Peptide chain elongation - Reactome            0.000020
# 1  Eukaryotic Translation Elongation - Reactome            0.000027
# 2   Extra-nuclear estrogen signaling - Reactome            0.000061
# 3                    eNOS activation - Reactome            0.000133
#
#    # genes in list  #genes in gocam  \
# 0                6               79
# 1                6               83
# 2                3               11
# 3                3               14
#
#                       shared gene products in gocam  \
# 0  [P62913, P05387, P62244, P62244, P46783, P62899]
# 1  [P62913, P05387, P62244, P62244, P46783, P62899]
# 2                          [P07900, P07900, P0DP23]
# 3                          [P07900, P07900, P0DP23]
#
#                                            url
# 0   http://model.geneontology.org/R-HSA-156902
# 1   http://model.geneontology.org/R-HSA-156842
# 2  http://model.geneontology.org/R-HSA-9009391
# 3   http://model.geneontology.org/R-HSA-203615

# %%
len(gene_list.g.drop_duplicates()),len(filtered_out_genes),len(filtered_list),len(not_converted)
# Out:
# (59, 38, 30, 1)

# %%
atlas_split = pd.read_csv('../test_data/split_cluster_363DG_isoform.csv').query('es > 1')
atlas_split['symbol?'] = atlas_split.name.apply(lambda x: x.split('-')[0])

# %%
atlas_split['symbol?'].to_csv('363DG_list.csv',index= False)

# %%
gene_list = pd.DataFrame({'g':atlas_split['symbol?']})
test_set, uniprot2input, not_converted = utils.convert_IDs(gene_list,'Gene Symbol')
x = pd.read_csv('../data/gocam_sizes_mouse.csv')
gocam_sizes = pd.Series(x.sizes.values,index=x.gocam)
Dict = utils.csv2dict('../data/ID2gocam_mouse.csv')
filtered_out_genes, filtered_list, setID2members_input_uni, setID2members_input, df_display= enrich.enrich(list(gene_list.g), 
    test_set, uniprot2input, gocam_sizes, Dict, show_significant=False)
df_display
# Out:
#                                                                                        title  \
# 0                                                   Citric acid cycle (TCA cycle) - Reactome
# 1                                          Reversible hydration of carbon dioxide - Reactome
# 2                          Erythrocytes take up carbon dioxide and release oxygen - Reactome
# 3                                       SUMO E3 ligases SUMOylate target proteins - Reactome
# 4    Negative regulation of activity of TFAP2 (AP-2) family transcription factors - Reactome
# ..                                                                                       ...
# 239                                       Resolution of Sister Chromatid Cohesion - Reactome
# 240                                                tRNA processing in the nucleus - Reactome
# 241                                                  The fatty acid cycling model - Reactome
# 242                                                    The proton buffering model - Reactome
# 243                                     Formation of ATP by chemiosmotic coupling - Reactome
#
#      pval (uncorrected)  # genes in list  #genes in gocam  \
# 0              0.000121                7               36
# 1              0.001412                4               16
# 2              0.002258                4               18
# 3              0.003057                2                3
# 4              0.003057                2                3
# ..                  ...              ...              ...
# 239            0.824883                2               96
# 240            0.848958                1               57
# 241            0.902236                1               70
# 242            0.902236                1               70
# 243            0.946600                1               88
#
#                                       shared gene products in gocam  \
# 0    [O75390, P09622, P31040, Q99798, P10515, P50213, sset:PDHA1,2]
# 1                            [P09622, P10515, P50213, sset:PDHA1,2]
# 2                            [P09622, P10515, P50213, sset:PDHA1,2]
# 3                                                  [Q9UBE0, Q9UBT2]
# 4                                                  [Q9UBE0, Q9UBT2]
# ..                                                              ...
# 239                                             [P36873, sset:DLIs]
# 240                                                        [Q9Y3I0]
# 241                                                        [P28331]
# 242                                                        [P28331]
# 243                                                        [P28331]
#
#                                              url
# 0      http://model.geneontology.org/R-HSA-71403
# 1    http://model.geneontology.org/R-HSA-1475029
# 2    http://model.geneontology.org/R-HSA-1237044
# 3    http://model.geneontology.org/R-HSA-3108232
# 4    http://model.geneontology.org/R-HSA-8866904
# ..                                           ...
# 239  http://model.geneontology.org/R-HSA-2500257
# 240  http://model.geneontology.org/R-HSA-6784531
# 241   http://model.geneontology.org/R-HSA-167826
# 242   http://model.geneontology.org/R-HSA-167827
# 243   http://model.geneontology.org/R-HSA-163210
#
# [244 rows x 6 columns]

# %%
len(gene_list.g.drop_duplicates()),len(filtered_out_genes),len(filtered_list),len(not_converted)
# Out:
# (247, 146, 129, 2)

# %%
#atlas_class_gene =pd.read_csv("/Volumes/NICK/Sternberg/class_DE_gene.csv").query('es > 1')
#atlas_class_gene['symbol?'] = atlas_class_gene.index_name.apply(lambda x: x.split('_')[1])
#atlas_class_GLUT_gene = atlas_class_gene[atlas_class_gene['index_name'].apply(lambda x: 'Glutamatergic' in x)]
#atlas_class_GABA_gene = atlas_class_gene[atlas_class_gene['index_name'].apply(lambda x: 'GABAergic' in x)]

# %%
#atlas_class_GLUT_gene['symbol?'].to_csv('../test_data/atlas_class_GLUT_gene.csv',index=False)
#atlas_class_GABA_gene['symbol?'].to_csv('../test_data/atlas_class_GABA_gene.csv',index=False)

# %%
atlas_class_GLUT_gene = pd.read_csv('../test_data/atlas_class_GLUT_gene.csv')
atlas_class_GABA_gene = pd.read_csv('../test_data/atlas_class_GABA_gene.csv')

# %%
gene_list = pd.DataFrame({'g':atlas_class_GLUT_gene['symbol?']})
test_set, uniprot2input, not_converted = utils.convert_IDs(gene_list,'Gene Symbol')
x = pd.read_csv('../data/gocam_sizes_mouse.csv')
gocam_sizes = pd.Series(x.sizes.values,index=x.gocam)
Dict = utils.csv2dict('../data/ID2gocam_mouse.csv')
filtered_out_genes, filtered_list, setID2members_input_uni, setID2members_input, df_display= enrich.enrich(list(gene_list.g), test_set, uniprot2input, gocam_sizes, Dict, alpha=.05)
df_display
# Out:
#                                                                        title  \
# 0  Unblocking of NMDA receptors, glutamate binding and activation - Reactome
# 1                                          Long-term potentiation - Reactome
# 2                                                 Ion homeostasis - Reactome
# 3                                       MAP2K and MAPK activation - Reactome
# 4                                    Activation of AMPA receptors - Reactome
# 5                       CLEC7A (Dectin-1) induces NFAT activation - Reactome
# 6           Ras activation upon Ca2+ influx through NMDA receptor - Reactome
# 7                                FCERI mediated Ca+2 mobilization - Reactome
# 8                              VEGFR2 mediated cell proliferation - Reactome
#
#    pval (uncorrected)  # genes in list  #genes in gocam  \
# 0        1.340241e-08                8               22
# 1        9.978431e-08                6               12
# 2        1.996578e-05                5               16
# 3        2.944847e-05                4                9
# 4        3.777037e-05                5               18
# 5        1.079835e-04                5               22
# 6        1.097441e-04                4               12
# 7        2.509272e-04                5               26
# 8        3.024470e-04                5               27
#
#                                                                          shared gene products in gocam  \
# 0  [P07196, Q96NW7, P42262, Q9P2U7, sset:CAMK2A,CAMK2B,(CAMK2D,CAMK2G), sset:GRIN1:GRIN2 NMDA recep...
# 1  [P07196, Q96NW7, sset:CAMK2A,CAMK2B,(CAMK2D,CAMK2G), sset:GRIN1:GRIN2 NMDA receptors, sset:p-T28...
# 2                [sset:ATP1A, sset:ITPR tetramers, sset:IP3R subunits, sset:RYR tetramers, sset:PMCAs]
# 3  [sset:RAF/MAPK scaffolds, sset:RAF activating kinases, sset:p-2S MAP2K homo/heterodimers, sset:M...
# 4  [P42262, Q9P2U7, sset:Ca impermeable AMPA receptors, sset:Ca permeable AMPA receptors, sset:CaMK...
# 5       [P63098, sset:ITPR tetramers, sset:PPP3CA,B, sset:IP3R subunits, sset:G-protein gamma subunit]
# 6                       [P07196, Q96NW7, sset:CAMK2A,CAMK2B,(CAMK2D,CAMK2G), sset:DLG1,DLG2,DLG3,DLG4]
# 7       [P63098, sset:ITPR tetramers, sset:PPP3CA,B, sset:IP3R subunits, sset:G-protein gamma subunit]
# 8  [sset:ITPR tetramers, sset:p-PKCA,p-PKCB,p-PKCZ,p-PKCD, sset:IP3R subunits, sset:G-protein gamma...
#
#                                            url
# 0   http://model.geneontology.org/R-HSA-438066
# 1  http://model.geneontology.org/R-HSA-9620244
# 2  http://model.geneontology.org/R-HSA-5578775
# 3  http://model.geneontology.org/R-HSA-5674135
# 4   http://model.geneontology.org/R-HSA-399710
# 5  http://model.geneontology.org/R-HSA-5607763
# 6   http://model.geneontology.org/R-HSA-442982
# 7  http://model.geneontology.org/R-HSA-2871809
# 8  http://model.geneontology.org/R-HSA-5218921

# %%
len(gene_list.g.drop_duplicates()),len(filtered_out_genes),len(filtered_list),len(not_converted)
# Out:
# (209, 143, 91, 4)

# %%
gene_list = pd.DataFrame({'g':atlas_class_GABA_gene['symbol?']})
test_set, uniprot2input, not_converted = utils.convert_IDs(gene_list,'Gene Symbol')
x = pd.read_csv('../data/gocam_sizes_mouse.csv')
gocam_sizes = pd.Series(x.sizes.values,index=x.gocam)
Dict = utils.csv2dict('../data/ID2gocam_mouse.csv')
filtered_out_genes, filtered_list, setID2members_input_uni, setID2members_input, df_display= enrich.enrich(list(gene_list.g), test_set, uniprot2input, gocam_sizes, Dict, alpha=.05)
df_display
# Out:
#                                                                title  \
# 0       GABA synthesis, release, reuptake and degradation - Reactome
# 1                              GABA B receptor activation - Reactome
# 2  Class C/3 (Metabotropic glutamate/pheromone receptors) - Reactome
# 3                                     Degradation of GABA - Reactome
# 4                            Activation of AMPA receptors - Reactome
#
#    pval (uncorrected)  # genes in list  #genes in gocam  \
# 0        3.085566e-07                5               26
# 1        6.997597e-07                4               13
# 2        6.997597e-07                4               13
# 3        1.040269e-04                2                3
# 4        1.478868e-04                3               18
#
#                                                     shared gene products in gocam  \
# 0    [Q05329, O14810, Q9H598, sset:SLC6A GABA transporters, sset:PXLP-GAD dimers]
# 1                                  [Q05329, O14810, Q9H598, sset:PXLP-GAD dimers]
# 2                                  [Q05329, O14810, Q9H598, sset:PXLP-GAD dimers]
# 3                                          [P80404, sset:SLC6A GABA transporters]
# 4  [O14810, sset:Ca impermeable AMPA receptors, sset:Ca permeable AMPA receptors]
#
#                                           url
# 0  http://model.geneontology.org/R-HSA-888590
# 1  http://model.geneontology.org/R-HSA-977444
# 2  http://model.geneontology.org/R-HSA-420499
# 3  http://model.geneontology.org/R-HSA-916853
# 4  http://model.geneontology.org/R-HSA-399710

# %%
len(gene_list.g.drop_duplicates()),len(filtered_out_genes),len(filtered_list),len(not_converted)
# Out:
# (78, 57, 24, 8)

# %% [markdown]
# atlas_subclass_gene =pd.read_csv("/Volumes/NICK/Sternberg/subclass_DE_gene.csv").query('es > 1')
# atlas_subclass_gene['symbol?'] = atlas_subclass_gene.index_name.apply(lambda x: x.split('_')[1])
# atlas_subclass_gene['subclass'] = atlas_subclass_gene.index_name.apply(lambda x: x.split('_')[0])
# atlas_subclass_gene.subclass.value_counts()
# atlas_subclass_SstC_gene = atlas_subclass_gene[atlas_subclass_gene['subclass']=='Vip']#Sst Pvalb Sncg Vip
# #atlas_csublass_GABA_gene = atlas_subclass_gene[atlas_subclass_gene['index_name'].apply(lambda x: 'GABAergic' in x)]

# %% [markdown]
# gene_list = pd.DataFrame({'g':atlas_subclass_SstC_gene['symbol?']})
# test_set, uniprot2input, not_converted = utils.convert_IDs(gene_list,'Gene Symbol')
# x = pd.read_csv('../data/gocam_sizes_mouse.csv')
# gocam_sizes = pd.Series(x.sizes.values,index=x.gocam)
# Dict = utils.csv2dict('../data/ID2gocam_mouse.csv')
# filtered_out_genes, filtered_list, setID2members_input_uni, setID2members_input, df_display= enrich.enrich(list(gene_list.g), test_set, uniprot2input, gocam_sizes, Dict, alpha=1)
# df_display

# %% [markdown]
# len(gene_list.g.drop_duplicates()),len(filtered_out_genes),len(filtered_list),len(not_converted)
